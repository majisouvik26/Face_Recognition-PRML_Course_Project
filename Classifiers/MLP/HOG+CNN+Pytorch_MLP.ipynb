# %%
import os
import cv2
import numpy as np
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
import os
from zipfile import ZipFile

# downloading the dataset
# !pip install kaggle


os.environ['KAGGLE_USERNAME'] = "majisouvik1099"
os.environ['KAGGLE_KEY'] = "9464225218d56f8bfea9dd9cc437489f"


# !kaggle datasets download -d jessicali9530/lfw-dataset


with ZipFile('lfw-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('lfw-dataset')


os.remove('lfw-dataset.zip')
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)
# lfw-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
def extract_features(image_path, model):
    image = Image.open(image_path).convert('RGB')
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    image = preprocess(image)
    image = image.unsqueeze(0)
    with torch.no_grad():
        features = model(image)
    features = features.squeeze(0)
    return features


def compute_hog(img):
    resized_img = resize(img, (128*4, 64*4))
    fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),
                    cells_per_block=(2, 2), visualize=True, multichannel=True)
    return fd


def get_pixel(img, center, x, y):
    new_value = 0
    try:
        if img[x][y] >= center:
            new_value = 1
    except:
        pass
    return new_value

def lbp_calculated_pixel(img, x, y):
    center = img[x][y]
    val_ar = []
    val_ar.append(get_pixel(img, center, x-1, y+1))
    val_ar.append(get_pixel(img, center, x, y+1))
    val_ar.append(get_pixel(img, center, x+1, y+1))
    val_ar.append(get_pixel(img, center, x+1, y))
    val_ar.append(get_pixel(img, center, x+1, y-1))
    val_ar.append(get_pixel(img, center, x, y-1))
    val_ar.append(get_pixel(img, center, x-1, y-1))
    val_ar.append(get_pixel(img, center, x-1, y))

    power_val = [1, 2, 4, 8, 16, 32, 64, 128]
    val = 0
    for i in range(len(val_ar)):
        val += val_ar[i] * power_val[i]
    return val

def calcLBP(img):
    height, width, channel = img.shape
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_lbp = np.zeros((height, width,3), np.uint8)
    for i in range(0, height):
        for j in range(0, width):
             img_lbp[i, j] = lbp_calculated_pixel(img_gray, i, j)
    hist_lbp = cv2.calcHist([img_lbp], [0], None, [256], [0, 256])
    return hist_lbp.flatten()

# %%
resnet = models.resnet50(pretrained=True)
resnet = nn.Sequential(*list(resnet.children())[:-1])
resnet.eval()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 88.5MB/s]
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (5): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (6): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (7): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %%
lfw_folder = '/content/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled'
X, y = [], []
for folder_name in os.listdir(lfw_folder):
    folder_path = os.path.join(lfw_folder, folder_name)
    if os.path.isdir(folder_path):
        num_images = len(os.listdir(folder_path))
        if num_images > 70:
            for image_name in os.listdir(folder_path):
                image_path = os.path.join(folder_path, image_name)
                image = imread(image_path)
                hog_feature = compute_hog(image)
                # lbp_feature = calcLBP(image)
                cnn_feature = extract_features(image_path, resnet).numpy()
                hog_feature = hog_feature.reshape(-1)
                # lbp_feature = lbp_feature.reshape(-1)
                cnn_feature = cnn_feature.flatten()
                combined_feature = np.concatenate((hog_feature, cnn_feature))

                X.append(combined_feature)
                y.append(folder_name)
# Out:
# <ipython-input-3-8d0f7df1f55f>:19: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),

# %%
np.array(X).shape
# Out:
# (1288, 72356)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train_encoded, dtype=torch.long)
y_test_tensor = torch.tensor(y_test_encoded, dtype=torch.long)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X_train_tensor = X_train_tensor.to(device)
X_test_tensor = X_test_tensor.to(device)
y_train_tensor = y_train_tensor.to(device)
y_test_tensor = y_test_tensor.to(device)

class MLPClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_hidden_layers):
        super(MLPClassifier, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_hidden_layers = num_hidden_layers


        self.input_layer = nn.Linear(input_size, hidden_size)


        self.hidden_layers = nn.ModuleList()
        for _ in range(num_hidden_layers):
            self.hidden_layers.append(nn.Linear(hidden_size, hidden_size))


        self.output_layer = nn.Linear(hidden_size, output_size)


        self.activation = nn.Tanh()

    def forward(self, x):
        x = self.activation(self.input_layer(x))
        for hidden_layer in self.hidden_layers:
            x = self.activation(hidden_layer(x))
        x = self.output_layer(x)
        return x


input_size = 72356
hidden_size = 512
output_size = len(np.unique(y_train_encoded))
num_hidden_layers = 2
model = MLPClassifier(input_size, hidden_size, output_size, num_hidden_layers)
model = model.to(device)


criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)


num_epochs = 500
best_accuracy = 0.0
lowest_overfitting = float('inf')
train_losses = []
test_losses = []
train_accuracies = []
test_accuracies = []

for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    loss.backward()
    optimizer.step()
    train_losses.append(loss.item())

    model.eval()
    with torch.no_grad():
        outputs = model(X_test_tensor)
        loss = criterion(outputs, y_test_tensor)
        test_losses.append(loss.item())
        _, predicted = torch.max(outputs, 1)
        correct = (predicted == y_test_tensor).sum().item()
        total = y_test_tensor.size(0)
        test_accuracy = correct / total
        test_accuracies.append(test_accuracy)

        _, predicted_train = torch.max(model(X_train_tensor), 1)
        correct_train = (predicted_train == y_train_tensor).sum().item()
        total_train = y_train_tensor.size(0)
        train_accuracy = correct_train / total_train
        train_accuracies.append(train_accuracy)

        if test_accuracy > best_accuracy:
            best_accuracy = test_accuracy
            torch.save(model.state_dict(), 'best_model.pth')

        if loss.item() < lowest_overfitting:
            lowest_overfitting = loss.item()

    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_losses[-1]}, Test Loss: {test_losses[-1]}, Train Accuracy: {train_accuracy}, Test Accuracy: {test_accuracy}')


best_model = MLPClassifier(input_size, hidden_size, output_size, num_hidden_layers)
best_model.load_state_dict(torch.load('best_model.pth'))
best_model = best_model.to(device)


print('Best Model:')
print(best_model)

print(f'Lowest Overfitting Loss: {lowest_overfitting}')


best_model.eval()
with torch.no_grad():
    outputs = best_model(X_test_tensor)
    _, predicted = torch.max(outputs, 1)
    print('Classification Report:')
    print(classification_report(y_test_tensor.cpu().numpy(), predicted.cpu().numpy()))
# Out:
# Epoch 1/500, Train Loss: 1.9498738050460815, Test Loss: 1.782470941543579, Train Accuracy: 0.4223300970873786, Test Accuracy: 0.3682170542635659
# Epoch 2/500, Train Loss: 1.6871592998504639, Test Loss: 1.7430553436279297, Train Accuracy: 0.4223300970873786, Test Accuracy: 0.3682170542635659
# Epoch 3/500, Train Loss: 1.6592466831207275, Test Loss: 1.7084791660308838, Train Accuracy: 0.4223300970873786, Test Accuracy: 0.3682170542635659
# Epoch 4/500, Train Loss: 1.6444393396377563, Test Loss: 1.696549892425537, Train Accuracy: 0.4223300970873786, Test Accuracy: 0.3682170542635659
# Epoch 5/500, Train Loss: 1.6412395238876343, Test Loss: 1.6889903545379639, Train Accuracy: 0.4223300970873786, Test Accuracy: 0.3682170542635659
# Epoch 6/500, Train Loss: 1.6292593479156494, Test Loss: 1.684151530265808, Train Accuracy: 0.4223300970873786, Test Accuracy: 0.3682170542635659
# Epoch 7/500, Train Loss: 1.6129438877105713, Test Loss: 1.6777164936065674, Train Accuracy: 0.4223300970873786, Test Accuracy: 0.3682170542635659
# Epoch 8/500, Train Loss: 1.5945895910263062, Test Loss: 1.6649268865585327, Train Accuracy: 0.4223300970873786, Test Accuracy: 0.3682170542635659
# Epoch 9/500, Train Loss: 1.5737667083740234, Test Loss: 1.6474348306655884, Train Accuracy: 0.4242718446601942, Test Accuracy: 0.37209302325581395
# Epoch 10/500, Train Loss: 1.5528939962387085, Test Loss: 1.6303032636642456, Train Accuracy: 0.4650485436893204, Test Accuracy: 0.4069767441860465
# Epoch 11/500, Train Loss: 1.5342943668365479, Test Loss: 1.6114511489868164, Train Accuracy: 0.4961165048543689, Test Accuracy: 0.4186046511627907
# Epoch 12/500, Train Loss: 1.5114617347717285, Test Loss: 1.5902403593063354, Train Accuracy: 0.5077669902912622, Test Accuracy: 0.43023255813953487
# Epoch 13/500, Train Loss: 1.4825056791305542, Test Loss: 1.5712088346481323, Train Accuracy: 0.5174757281553398, Test Accuracy: 0.437984496124031
# Epoch 14/500, Train Loss: 1.4544111490249634, Test Loss: 1.5504987239837646, Train Accuracy: 0.529126213592233, Test Accuracy: 0.46124031007751937
# Epoch 15/500, Train Loss: 1.427412509918213, Test Loss: 1.5249375104904175, Train Accuracy: 0.5436893203883495, Test Accuracy: 0.4844961240310077
# Epoch 16/500, Train Loss: 1.3992245197296143, Test Loss: 1.5004299879074097, Train Accuracy: 0.5504854368932038, Test Accuracy: 0.49612403100775193
# Epoch 17/500, Train Loss: 1.3711410760879517, Test Loss: 1.4786251783370972, Train Accuracy: 0.554368932038835, Test Accuracy: 0.49612403100775193
# Epoch 18/500, Train Loss: 1.3402434587478638, Test Loss: 1.4594969749450684, Train Accuracy: 0.5563106796116505, Test Accuracy: 0.49612403100775193
# Epoch 19/500, Train Loss: 1.3072421550750732, Test Loss: 1.44041109085083, Train Accuracy: 0.5621359223300971, Test Accuracy: 0.49612403100775193
# Epoch 20/500, Train Loss: 1.2748870849609375, Test Loss: 1.4148635864257812, Train Accuracy: 0.5689320388349515, Test Accuracy: 0.5038759689922481
# Epoch 21/500, Train Loss: 1.240913987159729, Test Loss: 1.3872408866882324, Train Accuracy: 0.570873786407767, Test Accuracy: 0.5038759689922481
# Epoch 22/500, Train Loss: 1.206194519996643, Test Loss: 1.3628804683685303, Train Accuracy: 0.5776699029126213, Test Accuracy: 0.5116279069767442
# Epoch 23/500, Train Loss: 1.1685807704925537, Test Loss: 1.3419898748397827, Train Accuracy: 0.5815533980582525, Test Accuracy: 0.5116279069767442
# Epoch 24/500, Train Loss: 1.1291236877441406, Test Loss: 1.3169242143630981, Train Accuracy: 0.5912621359223301, Test Accuracy: 0.5232558139534884
# Epoch 25/500, Train Loss: 1.088700532913208, Test Loss: 1.2842732667922974, Train Accuracy: 0.6077669902912621, Test Accuracy: 0.5310077519379846
# Epoch 26/500, Train Loss: 1.0461645126342773, Test Loss: 1.2513471841812134, Train Accuracy: 0.6281553398058253, Test Accuracy: 0.5348837209302325
# Epoch 27/500, Train Loss: 1.0011603832244873, Test Loss: 1.2204362154006958, Train Accuracy: 0.6485436893203883, Test Accuracy: 0.5465116279069767
# Epoch 28/500, Train Loss: 0.9551236033439636, Test Loss: 1.184024691581726, Train Accuracy: 0.6776699029126214, Test Accuracy: 0.5697674418604651
# Epoch 29/500, Train Loss: 0.9090233445167542, Test Loss: 1.144044041633606, Train Accuracy: 0.7116504854368932, Test Accuracy: 0.5968992248062015
# Epoch 30/500, Train Loss: 0.8624842762947083, Test Loss: 1.1098068952560425, Train Accuracy: 0.7281553398058253, Test Accuracy: 0.6085271317829457
# Epoch 31/500, Train Loss: 0.8150920271873474, Test Loss: 1.075606107711792, Train Accuracy: 0.7543689320388349, Test Accuracy: 0.627906976744186
# Epoch 32/500, Train Loss: 0.7680218815803528, Test Loss: 1.0347614288330078, Train Accuracy: 0.8038834951456311, Test Accuracy: 0.6550387596899225
# Epoch 33/500, Train Loss: 0.721119225025177, Test Loss: 0.9998987317085266, Train Accuracy: 0.8300970873786407, Test Accuracy: 0.6666666666666666
# Epoch 34/500, Train Loss: 0.6752688884735107, Test Loss: 0.9674805402755737, Train Accuracy: 0.8611650485436894, Test Accuracy: 0.6821705426356589
# Epoch 35/500, Train Loss: 0.6310124397277832, Test Loss: 0.9304006099700928, Train Accuracy: 0.8844660194174757, Test Accuracy: 0.7209302325581395
# Epoch 36/500, Train Loss: 0.5878037214279175, Test Loss: 0.9000930190086365, Train Accuracy: 0.8941747572815534, Test Accuracy: 0.7248062015503876
# Epoch 37/500, Train Loss: 0.5454304218292236, Test Loss: 0.8657052516937256, Train Accuracy: 0.9097087378640777, Test Accuracy: 0.748062015503876
# Epoch 38/500, Train Loss: 0.5045611262321472, Test Loss: 0.83211749792099, Train Accuracy: 0.9242718446601942, Test Accuracy: 0.7713178294573644
# Epoch 39/500, Train Loss: 0.4652269780635834, Test Loss: 0.8052284717559814, Train Accuracy: 0.9339805825242719, Test Accuracy: 0.7829457364341085
# Epoch 40/500, Train Loss: 0.4267600178718567, Test Loss: 0.7728954553604126, Train Accuracy: 0.9436893203883495, Test Accuracy: 0.7984496124031008
# Epoch 41/500, Train Loss: 0.3894426226615906, Test Loss: 0.7465976476669312, Train Accuracy: 0.9485436893203884, Test Accuracy: 0.7984496124031008
# Epoch 42/500, Train Loss: 0.3540717363357544, Test Loss: 0.7195695042610168, Train Accuracy: 0.9592233009708738, Test Accuracy: 0.7945736434108527
# Epoch 43/500, Train Loss: 0.321109801530838, Test Loss: 0.6908315420150757, Train Accuracy: 0.9699029126213592, Test Accuracy: 0.810077519379845
# Epoch 44/500, Train Loss: 0.29065993428230286, Test Loss: 0.6691623330116272, Train Accuracy: 0.974757281553398, Test Accuracy: 0.8217054263565892
# Epoch 45/500, Train Loss: 0.2626912295818329, Test Loss: 0.6456257104873657, Train Accuracy: 0.9825242718446602, Test Accuracy: 0.8255813953488372
# Epoch 46/500, Train Loss: 0.2371203899383545, Test Loss: 0.6230348348617554, Train Accuracy: 0.9893203883495145, Test Accuracy: 0.8410852713178295
# Epoch 47/500, Train Loss: 0.21367008984088898, Test Loss: 0.6056631803512573, Train Accuracy: 0.9941747572815534, Test Accuracy: 0.8333333333333334
# Epoch 48/500, Train Loss: 0.1921762228012085, Test Loss: 0.5868040919303894, Train Accuracy: 0.9951456310679612, Test Accuracy: 0.8410852713178295
# Epoch 49/500, Train Loss: 0.17280396819114685, Test Loss: 0.5678467750549316, Train Accuracy: 0.9990291262135922, Test Accuracy: 0.8488372093023255
# Epoch 50/500, Train Loss: 0.15549413859844208, Test Loss: 0.5533932447433472, Train Accuracy: 1.0, Test Accuracy: 0.8488372093023255
# Epoch 51/500, Train Loss: 0.13996022939682007, Test Loss: 0.539611279964447, Train Accuracy: 1.0, Test Accuracy: 0.8488372093023255
# Epoch 52/500, Train Loss: 0.126054048538208, Test Loss: 0.5236674547195435, Train Accuracy: 1.0, Test Accuracy: 0.8527131782945736
# Epoch 53/500, Train Loss: 0.1135031133890152, Test Loss: 0.5098223686218262, Train Accuracy: 1.0, Test Accuracy: 0.8527131782945736
# Epoch 54/500, Train Loss: 0.10222449898719788, Test Loss: 0.49949634075164795, Train Accuracy: 1.0, Test Accuracy: 0.8565891472868217
# Epoch 55/500, Train Loss: 0.09212905168533325, Test Loss: 0.4894302189350128, Train Accuracy: 1.0, Test Accuracy: 0.8565891472868217
# Epoch 56/500, Train Loss: 0.08318975567817688, Test Loss: 0.4778776466846466, Train Accuracy: 1.0, Test Accuracy: 0.8682170542635659
# Epoch 57/500, Train Loss: 0.07527894526720047, Test Loss: 0.46712934970855713, Train Accuracy: 1.0, Test Accuracy: 0.875968992248062
# Epoch 58/500, Train Loss: 0.06830020248889923, Test Loss: 0.4587914049625397, Train Accuracy: 1.0, Test Accuracy: 0.875968992248062
# Epoch 59/500, Train Loss: 0.062123384326696396, Test Loss: 0.4518253803253174, Train Accuracy: 1.0, Test Accuracy: 0.875968992248062
# Epoch 60/500, Train Loss: 0.056667689234018326, Test Loss: 0.44435611367225647, Train Accuracy: 1.0, Test Accuracy: 0.875968992248062
# Epoch 61/500, Train Loss: 0.05184184014797211, Test Loss: 0.43625953793525696, Train Accuracy: 1.0, Test Accuracy: 0.875968992248062
# Epoch 62/500, Train Loss: 0.04756594076752663, Test Loss: 0.42903587222099304, Train Accuracy: 1.0, Test Accuracy: 0.875968992248062
# Epoch 63/500, Train Loss: 0.043782200664281845, Test Loss: 0.4237515926361084, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 64/500, Train Loss: 0.04042390361428261, Test Loss: 0.42011818289756775, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 65/500, Train Loss: 0.037438053637742996, Test Loss: 0.41692590713500977, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 66/500, Train Loss: 0.0347803570330143, Test Loss: 0.41311025619506836, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 67/500, Train Loss: 0.03240447863936424, Test Loss: 0.408584326505661, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 68/500, Train Loss: 0.030275171622633934, Test Loss: 0.4040563404560089, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 69/500, Train Loss: 0.02836758829653263, Test Loss: 0.40025731921195984, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 70/500, Train Loss: 0.02665814384818077, Test Loss: 0.3974341154098511, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 71/500, Train Loss: 0.02512308955192566, Test Loss: 0.3953153192996979, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 72/500, Train Loss: 0.023738354444503784, Test Loss: 0.39339619874954224, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 73/500, Train Loss: 0.02248181588947773, Test Loss: 0.3913124203681946, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 74/500, Train Loss: 0.021337127313017845, Test Loss: 0.38904017210006714, Train Accuracy: 1.0, Test Accuracy: 0.875968992248062
# Epoch 75/500, Train Loss: 0.020293856039643288, Test Loss: 0.38682085275650024, Train Accuracy: 1.0, Test Accuracy: 0.875968992248062
# Epoch 76/500, Train Loss: 0.019343562424182892, Test Loss: 0.3849363923072815, Train Accuracy: 1.0, Test Accuracy: 0.875968992248062
# Epoch 77/500, Train Loss: 0.01847660169005394, Test Loss: 0.3835269510746002, Train Accuracy: 1.0, Test Accuracy: 0.875968992248062
# Epoch 78/500, Train Loss: 0.017682800069451332, Test Loss: 0.38253042101860046, Train Accuracy: 1.0, Test Accuracy: 0.875968992248062
# Epoch 79/500, Train Loss: 0.01695358380675316, Test Loss: 0.3817293345928192, Train Accuracy: 1.0, Test Accuracy: 0.875968992248062
# Epoch 80/500, Train Loss: 0.016282277181744576, Test Loss: 0.38086387515068054, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 81/500, Train Loss: 0.015663111582398415, Test Loss: 0.3797571659088135, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 82/500, Train Loss: 0.015090836212038994, Test Loss: 0.37839046120643616, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 83/500, Train Loss: 0.014560862444341183, Test Loss: 0.37689128518104553, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 84/500, Train Loss: 0.01406929548829794, Test Loss: 0.37545493245124817, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 85/500, Train Loss: 0.013612625189125538, Test Loss: 0.37425127625465393, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 86/500, Train Loss: 0.0131875304505229, Test Loss: 0.3733619153499603, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 87/500, Train Loss: 0.012790998443961143, Test Loss: 0.37276491522789, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 88/500, Train Loss: 0.0124203497543931, Test Loss: 0.37235862016677856, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 89/500, Train Loss: 0.01207313034683466, Test Loss: 0.3720092177391052, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 90/500, Train Loss: 0.011747034266591072, Test Loss: 0.3716030716896057, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 91/500, Train Loss: 0.011439965106546879, Test Loss: 0.3710843622684479, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 92/500, Train Loss: 0.011150147765874863, Test Loss: 0.3704650402069092, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 93/500, Train Loss: 0.010876225307583809, Test Loss: 0.36980634927749634, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 94/500, Train Loss: 0.010617061518132687, Test Loss: 0.36918625235557556, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 95/500, Train Loss: 0.010371629148721695, Test Loss: 0.3686666786670685, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 96/500, Train Loss: 0.01013890653848648, Test Loss: 0.36827266216278076, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 97/500, Train Loss: 0.009917904622852802, Test Loss: 0.3679881989955902, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 98/500, Train Loss: 0.009707704186439514, Test Loss: 0.36776646971702576, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 99/500, Train Loss: 0.009507446549832821, Test Loss: 0.3675488531589508, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 100/500, Train Loss: 0.009316345676779747, Test Loss: 0.36728623509407043, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 101/500, Train Loss: 0.009133686311542988, Test Loss: 0.3669548034667969, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 102/500, Train Loss: 0.008958828635513783, Test Loss: 0.36656153202056885, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 103/500, Train Loss: 0.008791215717792511, Test Loss: 0.36613890528678894, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 104/500, Train Loss: 0.008630369789898396, Test Loss: 0.365731418132782, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 105/500, Train Loss: 0.008475868962705135, Test Loss: 0.36537957191467285, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 106/500, Train Loss: 0.008327299728989601, Test Loss: 0.3651079833507538, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 107/500, Train Loss: 0.008184289559721947, Test Loss: 0.36491823196411133, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 108/500, Train Loss: 0.008046472445130348, Test Loss: 0.3647901713848114, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 109/500, Train Loss: 0.007913523353636265, Test Loss: 0.36468935012817383, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 110/500, Train Loss: 0.0077851396054029465, Test Loss: 0.36457616090774536, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 111/500, Train Loss: 0.007661043666303158, Test Loss: 0.36441782116889954, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 112/500, Train Loss: 0.007540981285274029, Test Loss: 0.36419519782066345, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 113/500, Train Loss: 0.0074247256852686405, Test Loss: 0.3639071583747864, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 114/500, Train Loss: 0.007312072906643152, Test Loss: 0.36356815695762634, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 115/500, Train Loss: 0.007202836684882641, Test Loss: 0.36320289969444275, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 116/500, Train Loss: 0.007096851710230112, Test Loss: 0.3628395199775696, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 117/500, Train Loss: 0.006993943825364113, Test Loss: 0.36250171065330505, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 118/500, Train Loss: 0.006893967278301716, Test Loss: 0.36220499873161316, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 119/500, Train Loss: 0.006796767469495535, Test Loss: 0.36195409297943115, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 120/500, Train Loss: 0.006702207028865814, Test Loss: 0.36174407601356506, Train Accuracy: 1.0, Test Accuracy: 0.8798449612403101
# Epoch 121/500, Train Loss: 0.00661015510559082, Test Loss: 0.36156386137008667, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 122/500, Train Loss: 0.006520495284348726, Test Loss: 0.3614002466201782, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 123/500, Train Loss: 0.006433114875108004, Test Loss: 0.3612416684627533, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 124/500, Train Loss: 0.006347915157675743, Test Loss: 0.3610813617706299, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 125/500, Train Loss: 0.006264795083552599, Test Loss: 0.36091792583465576, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 126/500, Train Loss: 0.006183681543916464, Test Loss: 0.3607546389102936, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 127/500, Train Loss: 0.0061044893227517605, Test Loss: 0.3605976998806, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 128/500, Train Loss: 0.006027142517268658, Test Loss: 0.3604530096054077, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 129/500, Train Loss: 0.005951570812612772, Test Loss: 0.3603244125843048, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 130/500, Train Loss: 0.005877714138478041, Test Loss: 0.3602120876312256, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 131/500, Train Loss: 0.005805496592074633, Test Loss: 0.3601120710372925, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 132/500, Train Loss: 0.005734854843467474, Test Loss: 0.36001741886138916, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 133/500, Train Loss: 0.005665745120495558, Test Loss: 0.35991957783699036, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 134/500, Train Loss: 0.005598097573965788, Test Loss: 0.3598105311393738, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 135/500, Train Loss: 0.005531867500394583, Test Loss: 0.35968491435050964, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 136/500, Train Loss: 0.0054670036770403385, Test Loss: 0.35954058170318604, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 137/500, Train Loss: 0.005403461400419474, Test Loss: 0.35937899351119995, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 138/500, Train Loss: 0.0053411927074193954, Test Loss: 0.35920560359954834, Train Accuracy: 1.0, Test Accuracy: 0.8875968992248062
# Epoch 139/500, Train Loss: 0.0052801636047661304, Test Loss: 0.35902780294418335, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 140/500, Train Loss: 0.005220335908234119, Test Loss: 0.35885366797447205, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 141/500, Train Loss: 0.005161665380001068, Test Loss: 0.3586903512477875, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 142/500, Train Loss: 0.005104123614728451, Test Loss: 0.35854318737983704, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 143/500, Train Loss: 0.005047670565545559, Test Loss: 0.35841476917266846, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 144/500, Train Loss: 0.004992281086742878, Test Loss: 0.3583046793937683, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 145/500, Train Loss: 0.004937910940498114, Test Loss: 0.35821032524108887, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 146/500, Train Loss: 0.004884541500359774, Test Loss: 0.3581277132034302, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 147/500, Train Loss: 0.004832140170037746, Test Loss: 0.3580518364906311, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 148/500, Train Loss: 0.004780682269483805, Test Loss: 0.35797858238220215, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 149/500, Train Loss: 0.004730138462036848, Test Loss: 0.3579045832157135, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 150/500, Train Loss: 0.004680487792938948, Test Loss: 0.3578279912471771, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 151/500, Train Loss: 0.004631704185158014, Test Loss: 0.3577482998371124, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 152/500, Train Loss: 0.004583763424307108, Test Loss: 0.3576662242412567, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 153/500, Train Loss: 0.00453664967790246, Test Loss: 0.35758325457572937, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 154/500, Train Loss: 0.004490335937589407, Test Loss: 0.357500821352005, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 155/500, Train Loss: 0.0044448040425777435, Test Loss: 0.3574204742908478, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 156/500, Train Loss: 0.004400025587528944, Test Loss: 0.3573429584503174, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 157/500, Train Loss: 0.004355995915830135, Test Loss: 0.3572680652141571, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 158/500, Train Loss: 0.004312683828175068, Test Loss: 0.35719558596611023, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 159/500, Train Loss: 0.004270084202289581, Test Loss: 0.35712456703186035, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 160/500, Train Loss: 0.004228171426802874, Test Loss: 0.3570541739463806, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 161/500, Train Loss: 0.004186926409602165, Test Loss: 0.35698366165161133, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 162/500, Train Loss: 0.004146344494074583, Test Loss: 0.356912761926651, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 163/500, Train Loss: 0.004106404259800911, Test Loss: 0.3568418323993683, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 164/500, Train Loss: 0.004067087545990944, Test Loss: 0.35677164793014526, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 165/500, Train Loss: 0.004028381779789925, Test Loss: 0.3567033112049103, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 166/500, Train Loss: 0.0039902799762785435, Test Loss: 0.3566381335258484, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 167/500, Train Loss: 0.003952763043344021, Test Loss: 0.35657742619514465, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 168/500, Train Loss: 0.003915817942470312, Test Loss: 0.3565220832824707, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 169/500, Train Loss: 0.003879434894770384, Test Loss: 0.3564721941947937, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 170/500, Train Loss: 0.003843604354187846, Test Loss: 0.35642796754837036, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 171/500, Train Loss: 0.0038083051331341267, Test Loss: 0.3563886284828186, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 172/500, Train Loss: 0.0037735351361334324, Test Loss: 0.356353223323822, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 173/500, Train Loss: 0.0037392801605165005, Test Loss: 0.35632023215293884, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 174/500, Train Loss: 0.0037055290304124355, Test Loss: 0.35628852248191833, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 175/500, Train Loss: 0.0036722791846841574, Test Loss: 0.356256902217865, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 176/500, Train Loss: 0.0036395101342350245, Test Loss: 0.3562244474887848, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 177/500, Train Loss: 0.003607217688113451, Test Loss: 0.35619041323661804, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 178/500, Train Loss: 0.003575392998754978, Test Loss: 0.35615473985671997, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 179/500, Train Loss: 0.0035440276842564344, Test Loss: 0.3561174273490906, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 180/500, Train Loss: 0.0035131077747792006, Test Loss: 0.3560790419578552, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 181/500, Train Loss: 0.003482629545032978, Test Loss: 0.356039822101593, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 182/500, Train Loss: 0.0034525792580097914, Test Loss: 0.3560005724430084, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 183/500, Train Loss: 0.0034229527227580547, Test Loss: 0.35596147179603577, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 184/500, Train Loss: 0.003393741324543953, Test Loss: 0.35592299699783325, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 185/500, Train Loss: 0.0033649334218353033, Test Loss: 0.3558853566646576, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 186/500, Train Loss: 0.0033365206327289343, Test Loss: 0.3558484613895416, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 187/500, Train Loss: 0.0033084985334426165, Test Loss: 0.3558124601840973, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 188/500, Train Loss: 0.003280856180936098, Test Loss: 0.35577714443206787, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 189/500, Train Loss: 0.0032535898499190807, Test Loss: 0.355742484331131, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 190/500, Train Loss: 0.0032266818452626467, Test Loss: 0.3557083308696747, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 191/500, Train Loss: 0.0032001351937651634, Test Loss: 0.35567501187324524, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 192/500, Train Loss: 0.003173937788233161, Test Loss: 0.3556423485279083, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 193/500, Train Loss: 0.003148092422634363, Test Loss: 0.3556109070777893, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 194/500, Train Loss: 0.00312257488258183, Test Loss: 0.35558074712753296, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 195/500, Train Loss: 0.003097390756011009, Test Loss: 0.3555522561073303, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 196/500, Train Loss: 0.0030725353863090277, Test Loss: 0.35552576184272766, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 197/500, Train Loss: 0.0030480024870485067, Test Loss: 0.3555014133453369, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 198/500, Train Loss: 0.0030237799510359764, Test Loss: 0.35547935962677, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 199/500, Train Loss: 0.002999864984303713, Test Loss: 0.35545966029167175, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 200/500, Train Loss: 0.0029762513004243374, Test Loss: 0.3554422855377197, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 201/500, Train Loss: 0.0029529437888413668, Test Loss: 0.35542693734169006, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 202/500, Train Loss: 0.0029299224261194468, Test Loss: 0.3554134964942932, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 203/500, Train Loss: 0.002907190937548876, Test Loss: 0.35540175437927246, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 204/500, Train Loss: 0.00288474396802485, Test Loss: 0.35539138317108154, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 205/500, Train Loss: 0.002862569410353899, Test Loss: 0.3553820848464966, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 206/500, Train Loss: 0.002840672619640827, Test Loss: 0.35537365078926086, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 207/500, Train Loss: 0.0028190501034259796, Test Loss: 0.3553659915924072, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 208/500, Train Loss: 0.002797682536765933, Test Loss: 0.3553590178489685, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 209/500, Train Loss: 0.0027765827253460884, Test Loss: 0.355352520942688, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 210/500, Train Loss: 0.0027557332068681717, Test Loss: 0.3553469181060791, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 211/500, Train Loss: 0.0027351337485015392, Test Loss: 0.3553415536880493, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 212/500, Train Loss: 0.0027147838845849037, Test Loss: 0.3553369343280792, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 213/500, Train Loss: 0.0026946731377393007, Test Loss: 0.3553328812122345, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 214/500, Train Loss: 0.002674804301932454, Test Loss: 0.35532936453819275, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 215/500, Train Loss: 0.0026551680639386177, Test Loss: 0.35532644391059875, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 216/500, Train Loss: 0.002635762095451355, Test Loss: 0.35532405972480774, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 217/500, Train Loss: 0.002616588259115815, Test Loss: 0.3553219437599182, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 218/500, Train Loss: 0.0025976295582950115, Test Loss: 0.3553202152252197, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 219/500, Train Loss: 0.0025788950733840466, Test Loss: 0.3553188741207123, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 220/500, Train Loss: 0.0025603817775845528, Test Loss: 0.3553175926208496, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 221/500, Train Loss: 0.002542068948969245, Test Loss: 0.3553165793418884, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 222/500, Train Loss: 0.0025239752139896154, Test Loss: 0.35531577467918396, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 223/500, Train Loss: 0.0025060793850570917, Test Loss: 0.35531502962112427, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 224/500, Train Loss: 0.0024883931037038565, Test Loss: 0.3553146421909332, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 225/500, Train Loss: 0.002470904029905796, Test Loss: 0.35531455278396606, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 226/500, Train Loss: 0.0024536107666790485, Test Loss: 0.3553147315979004, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 227/500, Train Loss: 0.002436511917039752, Test Loss: 0.35531511902809143, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 228/500, Train Loss: 0.002419603755697608, Test Loss: 0.3553161919116974, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 229/500, Train Loss: 0.002402881160378456, Test Loss: 0.35531771183013916, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 230/500, Train Loss: 0.0023863431997597218, Test Loss: 0.35531967878341675, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 231/500, Train Loss: 0.0023699866142123938, Test Loss: 0.3553221821784973, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 232/500, Train Loss: 0.002353812102228403, Test Loss: 0.35532525181770325, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 233/500, Train Loss: 0.00233781011775136, Test Loss: 0.3553287088871002, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 234/500, Train Loss: 0.002321983454748988, Test Loss: 0.35533270239830017, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 235/500, Train Loss: 0.0023063260596245527, Test Loss: 0.35533711314201355, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 236/500, Train Loss: 0.0022908358369022608, Test Loss: 0.35534194111824036, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 237/500, Train Loss: 0.002275515114888549, Test Loss: 0.35534724593162537, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 238/500, Train Loss: 0.0022603552788496017, Test Loss: 0.3553529381752014, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 239/500, Train Loss: 0.0022453591227531433, Test Loss: 0.35535910725593567, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 240/500, Train Loss: 0.002230518264696002, Test Loss: 0.355365514755249, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 241/500, Train Loss: 0.0022158357314765453, Test Loss: 0.3553723096847534, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 242/500, Train Loss: 0.002201307099312544, Test Loss: 0.3553796410560608, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 243/500, Train Loss: 0.0021869277115911245, Test Loss: 0.3553873300552368, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 244/500, Train Loss: 0.002172702457755804, Test Loss: 0.35539543628692627, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 245/500, Train Loss: 0.002158620860427618, Test Loss: 0.3554040193557739, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 246/500, Train Loss: 0.0021446847822517157, Test Loss: 0.3554130494594574, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 247/500, Train Loss: 0.002130894921720028, Test Loss: 0.3554225265979767, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 248/500, Train Loss: 0.0021172447595745325, Test Loss: 0.35543251037597656, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 249/500, Train Loss: 0.0021037328988313675, Test Loss: 0.3554427921772003, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 250/500, Train Loss: 0.0020903584081679583, Test Loss: 0.35545358061790466, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 251/500, Train Loss: 0.002077121753245592, Test Loss: 0.3554646670818329, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 252/500, Train Loss: 0.0020640131551772356, Test Loss: 0.3554760813713074, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 253/500, Train Loss: 0.0020510347094386816, Test Loss: 0.3554880619049072, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 254/500, Train Loss: 0.0020381940994411707, Test Loss: 0.35550016164779663, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 255/500, Train Loss: 0.0020254747942090034, Test Loss: 0.3555126488208771, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 256/500, Train Loss: 0.0020128879696130753, Test Loss: 0.35552549362182617, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 257/500, Train Loss: 0.0020004219841212034, Test Loss: 0.35553866624832153, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 258/500, Train Loss: 0.0019880752079188824, Test Loss: 0.3555521070957184, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 259/500, Train Loss: 0.001975852297618985, Test Loss: 0.3555658757686615, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 260/500, Train Loss: 0.001963753718882799, Test Loss: 0.3555799424648285, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 261/500, Train Loss: 0.0019517689943313599, Test Loss: 0.3555942475795746, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 262/500, Train Loss: 0.00193989765830338, Test Loss: 0.35560882091522217, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 263/500, Train Loss: 0.0019281446002423763, Test Loss: 0.35562360286712646, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 264/500, Train Loss: 0.0019165044650435448, Test Loss: 0.3556388020515442, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 265/500, Train Loss: 0.0019049764377996325, Test Loss: 0.3556540608406067, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 266/500, Train Loss: 0.0018935539992526174, Test Loss: 0.35566970705986023, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 267/500, Train Loss: 0.001882247976027429, Test Loss: 0.35568562150001526, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 268/500, Train Loss: 0.0018710405565798283, Test Loss: 0.35570159554481506, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 269/500, Train Loss: 0.0018599455943331122, Test Loss: 0.35571786761283875, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 270/500, Train Loss: 0.0018489505164325237, Test Loss: 0.35573437809944153, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 271/500, Train Loss: 0.0018380597466602921, Test Loss: 0.3557509481906891, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 272/500, Train Loss: 0.001827273634262383, Test Loss: 0.3557678461074829, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 273/500, Train Loss: 0.0018165863584727049, Test Loss: 0.35578489303588867, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 274/500, Train Loss: 0.0018059981521219015, Test Loss: 0.35580214858055115, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 275/500, Train Loss: 0.0017955085495486856, Test Loss: 0.35581955313682556, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 276/500, Train Loss: 0.0017851142911240458, Test Loss: 0.35583698749542236, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 277/500, Train Loss: 0.0017748131649568677, Test Loss: 0.35585489869117737, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 278/500, Train Loss: 0.001764611224643886, Test Loss: 0.35587283968925476, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 279/500, Train Loss: 0.0017545023001730442, Test Loss: 0.3558911085128784, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 280/500, Train Loss: 0.0017444784753024578, Test Loss: 0.35590946674346924, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 281/500, Train Loss: 0.0017345543019473553, Test Loss: 0.35592812299728394, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 282/500, Train Loss: 0.001724713365547359, Test Loss: 0.35594692826271057, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 283/500, Train Loss: 0.0017149649793282151, Test Loss: 0.35596591234207153, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 284/500, Train Loss: 0.0017052999464794993, Test Loss: 0.35598522424697876, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 285/500, Train Loss: 0.0016957259504124522, Test Loss: 0.3560046851634979, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 286/500, Train Loss: 0.0016862329794093966, Test Loss: 0.35602429509162903, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 287/500, Train Loss: 0.0016768246423453093, Test Loss: 0.35604411363601685, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 288/500, Train Loss: 0.0016675017541274428, Test Loss: 0.35606420040130615, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 289/500, Train Loss: 0.0016582563985139132, Test Loss: 0.3560844659805298, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 290/500, Train Loss: 0.0016490976558998227, Test Loss: 0.35610491037368774, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 291/500, Train Loss: 0.0016400158638134599, Test Loss: 0.3561255931854248, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 292/500, Train Loss: 0.001631017541512847, Test Loss: 0.3561463952064514, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 293/500, Train Loss: 0.0016220962861552835, Test Loss: 0.3561674654483795, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 294/500, Train Loss: 0.0016132490709424019, Test Loss: 0.35618868470191956, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 295/500, Train Loss: 0.001604479388333857, Test Loss: 0.35621026158332825, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 296/500, Train Loss: 0.001595781883224845, Test Loss: 0.3562319576740265, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 297/500, Train Loss: 0.0015871634241193533, Test Loss: 0.35625380277633667, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 298/500, Train Loss: 0.001578619470819831, Test Loss: 0.35627585649490356, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 299/500, Train Loss: 0.0015701430384069681, Test Loss: 0.3562983274459839, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 300/500, Train Loss: 0.0015617433236911893, Test Loss: 0.35632073879241943, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 301/500, Train Loss: 0.0015534148551523685, Test Loss: 0.35634350776672363, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 302/500, Train Loss: 0.001545157516375184, Test Loss: 0.35636648535728455, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 303/500, Train Loss: 0.001536963740363717, Test Loss: 0.356389582157135, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 304/500, Train Loss: 0.0015288431895896792, Test Loss: 0.3564128875732422, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 305/500, Train Loss: 0.0015207917895168066, Test Loss: 0.3564363420009613, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 306/500, Train Loss: 0.0015128061641007662, Test Loss: 0.3564600348472595, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 307/500, Train Loss: 0.0015048823552206159, Test Loss: 0.35648393630981445, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 308/500, Train Loss: 0.0014970282791182399, Test Loss: 0.35650789737701416, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 309/500, Train Loss: 0.001489233341999352, Test Loss: 0.35653209686279297, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 310/500, Train Loss: 0.0014815096510574222, Test Loss: 0.35655641555786133, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 311/500, Train Loss: 0.0014738484751433134, Test Loss: 0.3565809428691864, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 312/500, Train Loss: 0.0014662457397207618, Test Loss: 0.3566056489944458, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 313/500, Train Loss: 0.0014587113400921226, Test Loss: 0.35663047432899475, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 314/500, Train Loss: 0.0014512328198179603, Test Loss: 0.35665562748908997, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 315/500, Train Loss: 0.0014438183279708028, Test Loss: 0.35668081045150757, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 316/500, Train Loss: 0.0014364584349095821, Test Loss: 0.3567062020301819, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 317/500, Train Loss: 0.0014291610568761826, Test Loss: 0.3567318320274353, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 318/500, Train Loss: 0.001421926193870604, Test Loss: 0.3567575216293335, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 319/500, Train Loss: 0.0014147459296509624, Test Loss: 0.35678353905677795, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 320/500, Train Loss: 0.0014076210791245103, Test Loss: 0.3568095564842224, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 321/500, Train Loss: 0.0014005532721057534, Test Loss: 0.3568357229232788, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 322/500, Train Loss: 0.0013935451861470938, Test Loss: 0.35686221718788147, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 323/500, Train Loss: 0.0013865868095308542, Test Loss: 0.3568887412548065, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 324/500, Train Loss: 0.0013796875718981028, Test Loss: 0.35691553354263306, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 325/500, Train Loss: 0.001372840371914208, Test Loss: 0.35694244503974915, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 326/500, Train Loss: 0.0013660439290106297, Test Loss: 0.3569694757461548, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 327/500, Train Loss: 0.0013593037147074938, Test Loss: 0.35699662566185, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 328/500, Train Loss: 0.0013526200782507658, Test Loss: 0.35702401399612427, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 329/500, Train Loss: 0.0013459798647090793, Test Loss: 0.35705146193504333, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 330/500, Train Loss: 0.0013393954141065478, Test Loss: 0.3570791184902191, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 331/500, Train Loss: 0.0013328602071851492, Test Loss: 0.3571069836616516, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 332/500, Train Loss: 0.0013263763394206762, Test Loss: 0.3571348488330841, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 333/500, Train Loss: 0.0013199468376114964, Test Loss: 0.3571629226207733, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 334/500, Train Loss: 0.0013135605258867145, Test Loss: 0.3571910560131073, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 335/500, Train Loss: 0.0013072240399196744, Test Loss: 0.35721930861473083, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 336/500, Train Loss: 0.0013009341200813651, Test Loss: 0.35724782943725586, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 337/500, Train Loss: 0.0012946956558153033, Test Loss: 0.3572763502597809, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 338/500, Train Loss: 0.0012885030591860414, Test Loss: 0.35730499029159546, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 339/500, Train Loss: 0.0012823547003790736, Test Loss: 0.35733380913734436, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 340/500, Train Loss: 0.0012762536061927676, Test Loss: 0.35736268758773804, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 341/500, Train Loss: 0.001270196633413434, Test Loss: 0.3573917746543884, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 342/500, Train Loss: 0.001264188438653946, Test Loss: 0.3574208617210388, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 343/500, Train Loss: 0.0012582242488861084, Test Loss: 0.3574502170085907, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 344/500, Train Loss: 0.0012523020850494504, Test Loss: 0.3574795424938202, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 345/500, Train Loss: 0.0012464233441278338, Test Loss: 0.35750898718833923, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 346/500, Train Loss: 0.0012405914021655917, Test Loss: 0.3575386106967926, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 347/500, Train Loss: 0.0012348018353804946, Test Loss: 0.35756829380989075, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 348/500, Train Loss: 0.001229053596034646, Test Loss: 0.35759809613227844, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 349/500, Train Loss: 0.0012233474990352988, Test Loss: 0.35762789845466614, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 350/500, Train Loss: 0.0012176823802292347, Test Loss: 0.35765787959098816, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# ...
# Epoch 391/500, Train Loss: 0.0010167299769818783, Test Loss: 0.3589397370815277, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 392/500, Train Loss: 0.001012499094940722, Test Loss: 0.3589719533920288, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 393/500, Train Loss: 0.0010082833468914032, Test Loss: 0.35900411009788513, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 394/500, Train Loss: 0.0010041086934506893, Test Loss: 0.35903629660606384, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 395/500, Train Loss: 0.0009999556932598352, Test Loss: 0.3590686321258545, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 396/500, Train Loss: 0.000995822250843048, Test Loss: 0.35910093784332275, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 397/500, Train Loss: 0.0009917212883010507, Test Loss: 0.3591333031654358, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 398/500, Train Loss: 0.0009876525728031993, Test Loss: 0.35916557908058167, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 399/500, Train Loss: 0.0009836015524342656, Test Loss: 0.3591979742050171, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 400/500, Train Loss: 0.0009795821970328689, Test Loss: 0.3592303693294525, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 401/500, Train Loss: 0.0009755860082805157, Test Loss: 0.35926276445388794, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 402/500, Train Loss: 0.0009716168278828263, Test Loss: 0.35929521918296814, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 403/500, Train Loss: 0.0009676676709204912, Test Loss: 0.3593275845050812, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 404/500, Train Loss: 0.0009637505281716585, Test Loss: 0.3593602776527405, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 405/500, Train Loss: 0.0009598543983884156, Test Loss: 0.3593927025794983, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 406/500, Train Loss: 0.0009559823083691299, Test Loss: 0.35942521691322327, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 407/500, Train Loss: 0.000952135247644037, Test Loss: 0.35945773124694824, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 408/500, Train Loss: 0.0009483151370659471, Test Loss: 0.35949039459228516, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 409/500, Train Loss: 0.0009445170289836824, Test Loss: 0.3595229387283325, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 410/500, Train Loss: 0.0009407403995282948, Test Loss: 0.35955554246902466, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 411/500, Train Loss: 0.0009369890904054046, Test Loss: 0.35958826541900635, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 412/500, Train Loss: 0.000933262926992029, Test Loss: 0.3596208989620209, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 413/500, Train Loss: 0.0009295592317357659, Test Loss: 0.3596534729003906, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 414/500, Train Loss: 0.0009258764330297709, Test Loss: 0.3596862554550171, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 415/500, Train Loss: 0.0009222207590937614, Test Loss: 0.3597189486026764, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 416/500, Train Loss: 0.0009185819653794169, Test Loss: 0.35975173115730286, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 417/500, Train Loss: 0.0009149683173745871, Test Loss: 0.35978442430496216, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 418/500, Train Loss: 0.0009113784180954099, Test Loss: 0.3598172068595886, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 419/500, Train Loss: 0.0009078109869733453, Test Loss: 0.35985004901885986, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 420/500, Train Loss: 0.0009042591555044055, Test Loss: 0.35988277196884155, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 421/500, Train Loss: 0.0009007386979646981, Test Loss: 0.35991552472114563, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 422/500, Train Loss: 0.0008972331997938454, Test Loss: 0.3599483072757721, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 423/500, Train Loss: 0.0008937494712881744, Test Loss: 0.35998108983039856, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 424/500, Train Loss: 0.0008902860572561622, Test Loss: 0.3600139617919922, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 425/500, Train Loss: 0.000886845460627228, Test Loss: 0.3600468933582306, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 426/500, Train Loss: 0.0008834286709316075, Test Loss: 0.36007973551750183, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 427/500, Train Loss: 0.0008800284122116864, Test Loss: 0.3601126968860626, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 428/500, Train Loss: 0.0008766474784351885, Test Loss: 0.36014559864997864, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 429/500, Train Loss: 0.0008732886635698378, Test Loss: 0.36017847061157227, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 430/500, Train Loss: 0.0008699469617567956, Test Loss: 0.36021140217781067, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 431/500, Train Loss: 0.0008666290086694062, Test Loss: 0.3602443337440491, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 432/500, Train Loss: 0.0008633282268419862, Test Loss: 0.3602772653102875, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 433/500, Train Loss: 0.000860049098264426, Test Loss: 0.36031028628349304, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 434/500, Train Loss: 0.0008567916811443865, Test Loss: 0.36034324765205383, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 435/500, Train Loss: 0.0008535485831089318, Test Loss: 0.3603762090206146, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 436/500, Train Loss: 0.0008503230637870729, Test Loss: 0.3604091703891754, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 437/500, Train Loss: 0.0008471205946989357, Test Loss: 0.3604421615600586, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 438/500, Train Loss: 0.0008439428056590259, Test Loss: 0.3604752719402313, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 439/500, Train Loss: 0.0008407763671129942, Test Loss: 0.36050817370414734, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 440/500, Train Loss: 0.0008376250043511391, Test Loss: 0.3605411648750305, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 441/500, Train Loss: 0.0008344919187948108, Test Loss: 0.36057427525520325, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 442/500, Train Loss: 0.0008313845028169453, Test Loss: 0.3606072664260864, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 443/500, Train Loss: 0.0008282963535748422, Test Loss: 0.36064034700393677, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 444/500, Train Loss: 0.0008252167608588934, Test Loss: 0.3606734275817871, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 445/500, Train Loss: 0.0008221649331972003, Test Loss: 0.36070650815963745, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 446/500, Train Loss: 0.0008191217784769833, Test Loss: 0.3607396185398102, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 447/500, Train Loss: 0.0008161006262525916, Test Loss: 0.36077260971069336, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 448/500, Train Loss: 0.000813095539342612, Test Loss: 0.3608057498931885, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 449/500, Train Loss: 0.000810112978797406, Test Loss: 0.3608388304710388, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 450/500, Train Loss: 0.0008071415359154344, Test Loss: 0.3608718514442444, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 451/500, Train Loss: 0.0008041866240091622, Test Loss: 0.36090487241744995, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 452/500, Train Loss: 0.0008012515027076006, Test Loss: 0.3609378933906555, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 453/500, Train Loss: 0.0007983325631357729, Test Loss: 0.36097103357315063, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 454/500, Train Loss: 0.00079542730236426, Test Loss: 0.3610040545463562, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 455/500, Train Loss: 0.0007925417157821357, Test Loss: 0.36103710532188416, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 456/500, Train Loss: 0.0007896729512140155, Test Loss: 0.36107027530670166, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 457/500, Train Loss: 0.0007868175744079053, Test Loss: 0.3611032962799072, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 458/500, Train Loss: 0.0007839815225452185, Test Loss: 0.3611363172531128, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 459/500, Train Loss: 0.0007811622926965356, Test Loss: 0.3611694574356079, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 460/500, Train Loss: 0.0007783508626744151, Test Loss: 0.3612024784088135, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 461/500, Train Loss: 0.0007755628903396428, Test Loss: 0.3612355887889862, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 462/500, Train Loss: 0.0007727869669906795, Test Loss: 0.36126869916915894, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 463/500, Train Loss: 0.0007700272835791111, Test Loss: 0.3613017797470093, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 464/500, Train Loss: 0.000767282210290432, Test Loss: 0.36133480072021484, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 465/500, Train Loss: 0.0007645530859008431, Test Loss: 0.36136797070503235, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 466/500, Train Loss: 0.0007618400268256664, Test Loss: 0.36140111088752747, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 467/500, Train Loss: 0.0007591373287141323, Test Loss: 0.3614341616630554, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 468/500, Train Loss: 0.000756457622628659, Test Loss: 0.3614673614501953, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 469/500, Train Loss: 0.0007537908968515694, Test Loss: 0.3615005910396576, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 470/500, Train Loss: 0.0007511322619393468, Test Loss: 0.36153364181518555, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 471/500, Train Loss: 0.0007484907400794327, Test Loss: 0.3615667223930359, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 472/500, Train Loss: 0.0007458670879714191, Test Loss: 0.3615998327732086, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 473/500, Train Loss: 0.000743251119274646, Test Loss: 0.36163297295570374, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 474/500, Train Loss: 0.0007406571530736983, Test Loss: 0.3616660535335541, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 475/500, Train Loss: 0.0007380717433989048, Test Loss: 0.36169907450675964, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 476/500, Train Loss: 0.0007355039706453681, Test Loss: 0.3617320954799652, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 477/500, Train Loss: 0.0007329483632929623, Test Loss: 0.3617652356624603, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 478/500, Train Loss: 0.0007304049795493484, Test Loss: 0.3617982566356659, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 479/500, Train Loss: 0.0007278788834810257, Test Loss: 0.36183109879493713, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 480/500, Train Loss: 0.0007253678049892187, Test Loss: 0.36186423897743225, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 481/500, Train Loss: 0.0007228681351989508, Test Loss: 0.3618972599506378, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 482/500, Train Loss: 0.0007203763816505671, Test Loss: 0.3619302809238434, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 483/500, Train Loss: 0.0007179044187068939, Test Loss: 0.3619632124900818, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 484/500, Train Loss: 0.0007154463091865182, Test Loss: 0.36199620366096497, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 485/500, Train Loss: 0.0007129940204322338, Test Loss: 0.3620293140411377, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 486/500, Train Loss: 0.0007105609984137118, Test Loss: 0.3620623052120209, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 487/500, Train Loss: 0.0007081375224515796, Test Loss: 0.3620954751968384, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 488/500, Train Loss: 0.0007057280163280666, Test Loss: 0.3621284067630768, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 489/500, Train Loss: 0.0007033309666439891, Test Loss: 0.3621614873409271, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 490/500, Train Loss: 0.0007009482942521572, Test Loss: 0.3621944189071655, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 491/500, Train Loss: 0.0006985734216868877, Test Loss: 0.3622274100780487, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 492/500, Train Loss: 0.0006962186889722943, Test Loss: 0.36226052045822144, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 493/500, Train Loss: 0.0006938715232536197, Test Loss: 0.3622935116291046, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 494/500, Train Loss: 0.000691539142280817, Test Loss: 0.36232641339302063, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 495/500, Train Loss: 0.0006892155506648123, Test Loss: 0.3623594045639038, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 496/500, Train Loss: 0.0006869040080346167, Test Loss: 0.3623923063278198, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 497/500, Train Loss: 0.0006846110336482525, Test Loss: 0.3624252378940582, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 498/500, Train Loss: 0.0006823260337114334, Test Loss: 0.3624582588672638, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 499/500, Train Loss: 0.0006800481351092458, Test Loss: 0.3624911308288574, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Epoch 500/500, Train Loss: 0.0006777856033295393, Test Loss: 0.3625240921974182, Train Accuracy: 1.0, Test Accuracy: 0.8837209302325582
# Best Model:
# MLPClassifier(
#   (input_layer): Linear(in_features=72356, out_features=512, bias=True)
#   (hidden_layers): ModuleList(
#     (0-1): 2 x Linear(in_features=512, out_features=512, bias=True)
#   )
#   (output_layer): Linear(in_features=512, out_features=7, bias=True)
#   (activation): Tanh()
# )
# Lowest Overfitting Loss: 0.35531455278396606
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.58      0.71        19
#            1       0.94      0.96      0.95        53
#            2       0.92      0.71      0.80        31
#            3       0.83      0.98      0.90        95
#            4       1.00      0.78      0.88        18
#            5       0.78      0.64      0.70        11
#            6       0.94      1.00      0.97        31
#
#     accuracy                           0.89       258
#    macro avg       0.90      0.81      0.84       258
# weighted avg       0.89      0.89      0.88       258

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Testing Accuracy')
plt.legend()
plt.show()
