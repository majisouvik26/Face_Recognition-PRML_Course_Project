# %%
import os
import cv2
import numpy as np
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier

# %%
import os
from zipfile import ZipFile


# !pip install kaggle


os.environ['KAGGLE_USERNAME'] = "parthhtrp"
os.environ['KAGGLE_KEY'] = "3c61ded81cf3887193f7a9ed32ce52b5"


# !kaggle datasets download -d jessicali9530/lfw-dataset


with ZipFile('lfw-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('lfw-dataset')


os.remove('lfw-dataset.zip')
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.6)
# Downloading lfw-dataset.zip to /content
#  88% 99.0M/112M [00:01<00:00, 90.4MB/s]
# 100% 112M/112M [00:01<00:00, 97.1MB/s]

# %%
import os

dataset_path = 'lfw-dataset'

# List all directories in the dataset folder
folders = [name for name in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, name))]

# Print the number of folders
print("Number of folders in the dataset:", len(folders))
# Out:
# Number of folders in the dataset: 1

# %%
import os

def print_folder_contents(folder_path, indent=''):
    # List all directories and files in the folder
    contents = os.listdir(folder_path)

    for item in contents:
        item_path = os.path.join(folder_path, item)

        # Check if the item is a directory
        if os.path.isdir(item_path):
            print(indent + "Folder:", item)
            print_folder_contents(item_path, indent + '  ')
        else:
            print(indent + "File:", item)

dataset_path = 'lfw-dataset'
x=0

# List all directories in the dataset folder
folders = [name for name in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, name))]

# Print number of folders
print("Number of folders in the dataset:", len(folders))

# Print details of each folder
for folder in folders:
    print("\nFolder:", folder)
    print_folder_contents(os.path.join(dataset_path, folder))
# Out:
# Streaming output truncated to the last 5000 lines.
#     File: Amanda_Coetzer_0002.jpg
#     File: Amanda_Coetzer_0001.jpg
#   Folder: Carla_Tricoli
#     File: Carla_Tricoli_0001.jpg
#   Folder: Akmal_Taher
#     File: Akmal_Taher_0001.jpg
#   Folder: Wendell_Bryant
#     File: Wendell_Bryant_0001.jpg
#   Folder: George_Galloway
#     File: George_Galloway_0003.jpg
#     File: George_Galloway_0002.jpg
#     File: George_Galloway_0004.jpg
#     File: George_Galloway_0001.jpg
#   Folder: Mireya_Elisa_Moscoso_Rodriguez
#     File: Mireya_Elisa_Moscoso_Rodriguez_0001.jpg
#   Folder: Dick_Latessa
#     File: Dick_Latessa_0001.jpg
#     File: Dick_Latessa_0002.jpg
#   Folder: Paul_Patton
#     File: Paul_Patton_0001.jpg
#     File: Paul_Patton_0002.jpg
#   Folder: Kurt_Busch
#     File: Kurt_Busch_0002.jpg
#     File: Kurt_Busch_0001.jpg
#   Folder: Kit_Bond
#     File: Kit_Bond_0001.jpg
#   Folder: Hermes_Gamonal
#     File: Hermes_Gamonal_0001.jpg
#   Folder: Lydia_Shum
#     File: Lydia_Shum_0001.jpg
#   Folder: David_Brent
#     File: David_Brent_0001.jpg
#   Folder: Roger_Machado
#     File: Roger_Machado_0001.jpg
#   Folder: Derek_King
#     File: Derek_King_0001.jpg
#   Folder: Kofi_Annan
#     File: Kofi_Annan_0029.jpg
#     File: Kofi_Annan_0017.jpg
#     File: Kofi_Annan_0021.jpg
#     File: Kofi_Annan_0018.jpg
#     File: Kofi_Annan_0013.jpg
#     File: Kofi_Annan_0026.jpg
#     File: Kofi_Annan_0007.jpg
#     File: Kofi_Annan_0022.jpg
#     File: Kofi_Annan_0006.jpg
#     File: Kofi_Annan_0027.jpg
#     File: Kofi_Annan_0003.jpg
#     File: Kofi_Annan_0032.jpg
#     File: Kofi_Annan_0002.jpg
#     File: Kofi_Annan_0019.jpg
#     File: Kofi_Annan_0024.jpg
#     File: Kofi_Annan_0008.jpg
#     File: Kofi_Annan_0015.jpg
#     File: Kofi_Annan_0004.jpg
#     File: Kofi_Annan_0014.jpg
#     File: Kofi_Annan_0010.jpg
#     File: Kofi_Annan_0016.jpg
#     File: Kofi_Annan_0001.jpg
#     File: Kofi_Annan_0031.jpg
#     File: Kofi_Annan_0023.jpg
#     File: Kofi_Annan_0011.jpg
#     File: Kofi_Annan_0012.jpg
#     File: Kofi_Annan_0005.jpg
#     File: Kofi_Annan_0028.jpg
#     File: Kofi_Annan_0025.jpg
#     File: Kofi_Annan_0030.jpg
#     File: Kofi_Annan_0020.jpg
#     File: Kofi_Annan_0009.jpg
#   Folder: Nora_Ephron
#     File: Nora_Ephron_0001.jpg
#   Folder: Anne_Heche
#     File: Anne_Heche_0001.jpg
#   Folder: Phillip_Fulmer
#     File: Phillip_Fulmer_0001.jpg
#   Folder: Pat_Burns
#     File: Pat_Burns_0002.jpg
#     File: Pat_Burns_0001.jpg
#   Folder: Nona_Gaye
#     File: Nona_Gaye_0001.jpg
#   Folder: Ryan_Nyquist
#     File: Ryan_Nyquist_0001.jpg
#   Folder: Daisy_Fuentes
#     File: Daisy_Fuentes_0003.jpg
#     File: Daisy_Fuentes_0002.jpg
#     File: Daisy_Fuentes_0001.jpg
#     File: Daisy_Fuentes_0004.jpg
#   Folder: Paul_Desmarais
#     File: Paul_Desmarais_0001.jpg
#   Folder: Monte_Kiffin
#     File: Monte_Kiffin_0001.jpg
#   Folder: Noel_Forgeard
#     File: Noel_Forgeard_0001.jpg
#   Folder: Leo_Ramirez
#     File: Leo_Ramirez_0001.jpg
#   Folder: Joe_Carnahan
#     File: Joe_Carnahan_0001.jpg
#   Folder: Isabela_Moraes
#     File: Isabela_Moraes_0001.jpg
#   Folder: Stefano_Accorsi
#     File: Stefano_Accorsi_0002.jpg
#     File: Stefano_Accorsi_0001.jpg
#   Folder: Azmi_Bishara
#     File: Azmi_Bishara_0001.jpg
#   Folder: Thomas_OBrien
#     File: Thomas_OBrien_0006.jpg
#     File: Thomas_OBrien_0008.jpg
#     File: Thomas_OBrien_0004.jpg
#     File: Thomas_OBrien_0001.jpg
#     File: Thomas_OBrien_0003.jpg
#     File: Thomas_OBrien_0009.jpg
#     File: Thomas_OBrien_0002.jpg
#     File: Thomas_OBrien_0005.jpg
#     File: Thomas_OBrien_0007.jpg
#   Folder: Manuel_Poggiali
#     File: Manuel_Poggiali_0001.jpg
#     File: Manuel_Poggiali_0002.jpg
#   Folder: Celso_Lafer
#     File: Celso_Lafer_0001.jpg
#   Folder: Ricardo_Maduro
#     File: Ricardo_Maduro_0001.jpg
#     File: Ricardo_Maduro_0002.jpg
#   Folder: Craig_Morgan
#     File: Craig_Morgan_0001.jpg
#   Folder: Iain_Duncan_Smith
#     File: Iain_Duncan_Smith_0004.jpg
#     File: Iain_Duncan_Smith_0002.jpg
#     File: Iain_Duncan_Smith_0001.jpg
#     File: Iain_Duncan_Smith_0003.jpg
#   Folder: Mayumi_Moriyama
#     File: Mayumi_Moriyama_0001.jpg
#   Folder: Bill_Richardson
#     File: Bill_Richardson_0001.jpg
#   Folder: Carol_Carmody
#     File: Carol_Carmody_0001.jpg
#   Folder: Dan_Monson
#     File: Dan_Monson_0001.jpg
#   Folder: Mahdi_Al_Bassam
#     File: Mahdi_Al_Bassam_0001.jpg
#   Folder: Thomas_Ulrich
#     File: Thomas_Ulrich_0001.jpg
#   Folder: Katerina_Smrzova
#     File: Katerina_Smrzova_0001.jpg
#   Folder: Anne_ONeil
#     File: Anne_ONeil_0001.jpg
#   Folder: Laurie_Chan
#     File: Laurie_Chan_0001.jpg
#   Folder: Clay_Campbell
#     File: Clay_Campbell_0001.jpg
#   Folder: Gong_Li
#     File: Gong_Li_0001.jpg
#   Folder: Kurt_Suzuki
#     File: Kurt_Suzuki_0001.jpg
#   Folder: Alfonso_Cuaron
#     File: Alfonso_Cuaron_0001.jpg
#   Folder: Alison_Lohman
#     File: Alison_Lohman_0001.jpg
#     File: Alison_Lohman_0002.jpg
#   Folder: Ana_Guevara
#     File: Ana_Guevara_0004.jpg
#     File: Ana_Guevara_0001.jpg
#     File: Ana_Guevara_0006.jpg
#     File: Ana_Guevara_0002.jpg
#     File: Ana_Guevara_0005.jpg
#     File: Ana_Guevara_0007.jpg
#     File: Ana_Guevara_0003.jpg
#   Folder: Colin_Powell
#     File: Colin_Powell_0013.jpg
#     File: Colin_Powell_0074.jpg
#     File: Colin_Powell_0079.jpg
#     File: Colin_Powell_0162.jpg
#     File: Colin_Powell_0181.jpg
#     File: Colin_Powell_0022.jpg
#     File: Colin_Powell_0036.jpg
#     File: Colin_Powell_0167.jpg
#     File: Colin_Powell_0011.jpg
#     File: Colin_Powell_0025.jpg
#     File: Colin_Powell_0072.jpg
#     File: Colin_Powell_0085.jpg
#     File: Colin_Powell_0091.jpg
#     File: Colin_Powell_0016.jpg
#     File: Colin_Powell_0063.jpg
#     File: Colin_Powell_0081.jpg
#     File: Colin_Powell_0225.jpg
#     File: Colin_Powell_0057.jpg
#     File: Colin_Powell_0230.jpg
#     File: Colin_Powell_0212.jpg
#     File: Colin_Powell_0005.jpg
#     File: Colin_Powell_0073.jpg
#     File: Colin_Powell_0060.jpg
#     File: Colin_Powell_0174.jpg
#     File: Colin_Powell_0068.jpg
#     File: Colin_Powell_0059.jpg
#     File: Colin_Powell_0203.jpg
#     File: Colin_Powell_0172.jpg
#     File: Colin_Powell_0061.jpg
#     File: Colin_Powell_0176.jpg
#     File: Colin_Powell_0008.jpg
#     File: Colin_Powell_0163.jpg
#     File: Colin_Powell_0197.jpg
#     File: Colin_Powell_0052.jpg
#     File: Colin_Powell_0214.jpg
#     File: Colin_Powell_0095.jpg
#     File: Colin_Powell_0003.jpg
#     File: Colin_Powell_0164.jpg
#     File: Colin_Powell_0175.jpg
#     File: Colin_Powell_0001.jpg
#     File: Colin_Powell_0021.jpg
#     File: Colin_Powell_0159.jpg
#     File: Colin_Powell_0148.jpg
#     File: Colin_Powell_0006.jpg
#     File: Colin_Powell_0137.jpg
#     File: Colin_Powell_0082.jpg
#     File: Colin_Powell_0127.jpg
#     File: Colin_Powell_0223.jpg
#     File: Colin_Powell_0195.jpg
#     File: Colin_Powell_0123.jpg
#     File: Colin_Powell_0020.jpg
#     File: Colin_Powell_0129.jpg
#     File: Colin_Powell_0023.jpg
#     File: Colin_Powell_0130.jpg
#     File: Colin_Powell_0051.jpg
#     File: Colin_Powell_0169.jpg
#     File: Colin_Powell_0028.jpg
#     File: Colin_Powell_0014.jpg
#     File: Colin_Powell_0232.jpg
#     File: Colin_Powell_0228.jpg
#     File: Colin_Powell_0032.jpg
#     File: Colin_Powell_0185.jpg
#     File: Colin_Powell_0208.jpg
#     File: Colin_Powell_0147.jpg
#     File: Colin_Powell_0041.jpg
#     File: Colin_Powell_0229.jpg
#     File: Colin_Powell_0004.jpg
#     File: Colin_Powell_0055.jpg
#     File: Colin_Powell_0066.jpg
#     File: Colin_Powell_0047.jpg
#     File: Colin_Powell_0038.jpg
#     File: Colin_Powell_0024.jpg
#     File: Colin_Powell_0012.jpg
#     File: Colin_Powell_0165.jpg
#     File: Colin_Powell_0220.jpg
#     File: Colin_Powell_0037.jpg
#     File: Colin_Powell_0140.jpg
#     File: Colin_Powell_0201.jpg
#     File: Colin_Powell_0094.jpg
#     File: Colin_Powell_0156.jpg
#     File: Colin_Powell_0087.jpg
#     File: Colin_Powell_0103.jpg
#     File: Colin_Powell_0097.jpg
#     File: Colin_Powell_0110.jpg
#     File: Colin_Powell_0083.jpg
#     File: Colin_Powell_0135.jpg
#     File: Colin_Powell_0043.jpg
#     File: Colin_Powell_0100.jpg
#     File: Colin_Powell_0150.jpg
#     File: Colin_Powell_0010.jpg
#     File: Colin_Powell_0188.jpg
#     File: Colin_Powell_0070.jpg
#     File: Colin_Powell_0155.jpg
#     File: Colin_Powell_0179.jpg
#     File: Colin_Powell_0056.jpg
#     File: Colin_Powell_0113.jpg
#     File: Colin_Powell_0018.jpg
#     File: Colin_Powell_0144.jpg
#     File: Colin_Powell_0170.jpg
#     File: Colin_Powell_0206.jpg
#     File: Colin_Powell_0205.jpg
#     File: Colin_Powell_0136.jpg
#     File: Colin_Powell_0111.jpg
#     File: Colin_Powell_0118.jpg
#     File: Colin_Powell_0078.jpg
#     File: Colin_Powell_0086.jpg
#     File: Colin_Powell_0045.jpg
#     File: Colin_Powell_0112.jpg
#     File: Colin_Powell_0200.jpg
#     File: Colin_Powell_0221.jpg
#     File: Colin_Powell_0121.jpg
#     File: Colin_Powell_0088.jpg
#     File: Colin_Powell_0209.jpg
#     File: Colin_Powell_0080.jpg
#     File: Colin_Powell_0145.jpg
#     File: Colin_Powell_0235.jpg
#     File: Colin_Powell_0142.jpg
#     File: Colin_Powell_0132.jpg
#     File: Colin_Powell_0067.jpg
#     File: Colin_Powell_0234.jpg
#     File: Colin_Powell_0125.jpg
#     File: Colin_Powell_0049.jpg
#     File: Colin_Powell_0141.jpg
#     File: Colin_Powell_0153.jpg
#     File: Colin_Powell_0062.jpg
#     File: Colin_Powell_0039.jpg
#     File: Colin_Powell_0009.jpg
#     File: Colin_Powell_0189.jpg
#     File: Colin_Powell_0204.jpg
#     File: Colin_Powell_0183.jpg
#     File: Colin_Powell_0199.jpg
#     File: Colin_Powell_0227.jpg
#     File: Colin_Powell_0076.jpg
#     File: Colin_Powell_0133.jpg
#     File: Colin_Powell_0236.jpg
#     File: Colin_Powell_0007.jpg
#     File: Colin_Powell_0152.jpg
#     File: Colin_Powell_0160.jpg
#     File: Colin_Powell_0090.jpg
#     File: Colin_Powell_0151.jpg
#     File: Colin_Powell_0139.jpg
#     File: Colin_Powell_0106.jpg
#     File: Colin_Powell_0071.jpg
#     File: Colin_Powell_0031.jpg
#     File: Colin_Powell_0177.jpg
#     File: Colin_Powell_0178.jpg
#     File: Colin_Powell_0138.jpg
#     File: Colin_Powell_0173.jpg
#     File: Colin_Powell_0186.jpg
#     File: Colin_Powell_0089.jpg
#     File: Colin_Powell_0002.jpg
#     File: Colin_Powell_0134.jpg
#     File: Colin_Powell_0126.jpg
#     File: Colin_Powell_0216.jpg
#     File: Colin_Powell_0158.jpg
#     File: Colin_Powell_0105.jpg
#     File: Colin_Powell_0210.jpg
#     File: Colin_Powell_0015.jpg
#     File: Colin_Powell_0102.jpg
#     File: Colin_Powell_0166.jpg
#     File: Colin_Powell_0180.jpg
#     File: Colin_Powell_0207.jpg
#     File: Colin_Powell_0215.jpg
#     File: Colin_Powell_0026.jpg
#     File: Colin_Powell_0226.jpg
#     File: Colin_Powell_0218.jpg
#     File: Colin_Powell_0161.jpg
#     File: Colin_Powell_0065.jpg
#     File: Colin_Powell_0231.jpg
#     File: Colin_Powell_0099.jpg
#     File: Colin_Powell_0075.jpg
#     File: Colin_Powell_0092.jpg
#     File: Colin_Powell_0196.jpg
#     File: Colin_Powell_0122.jpg
#     File: Colin_Powell_0190.jpg
#     File: Colin_Powell_0222.jpg
#     File: Colin_Powell_0017.jpg
#     File: Colin_Powell_0114.jpg
#     File: Colin_Powell_0108.jpg
#     File: Colin_Powell_0101.jpg
#     File: Colin_Powell_0033.jpg
#     File: Colin_Powell_0034.jpg
#     File: Colin_Powell_0219.jpg
#     File: Colin_Powell_0040.jpg
#     File: Colin_Powell_0044.jpg
#     File: Colin_Powell_0120.jpg
#     File: Colin_Powell_0064.jpg
#     File: Colin_Powell_0211.jpg
#     File: Colin_Powell_0194.jpg
#     File: Colin_Powell_0192.jpg
#     File: Colin_Powell_0116.jpg
#     File: Colin_Powell_0143.jpg
#     File: Colin_Powell_0117.jpg
#     File: Colin_Powell_0029.jpg
#     File: Colin_Powell_0193.jpg
#     File: Colin_Powell_0107.jpg
#     File: Colin_Powell_0054.jpg
#     File: Colin_Powell_0149.jpg
#     File: Colin_Powell_0058.jpg
#     File: Colin_Powell_0019.jpg
#     File: Colin_Powell_0042.jpg
#     File: Colin_Powell_0035.jpg
#     File: Colin_Powell_0096.jpg
#     File: Colin_Powell_0093.jpg
#     File: Colin_Powell_0048.jpg
#     File: Colin_Powell_0104.jpg
#     File: Colin_Powell_0224.jpg
#     File: Colin_Powell_0077.jpg
#     File: Colin_Powell_0027.jpg
#     File: Colin_Powell_0182.jpg
#     File: Colin_Powell_0084.jpg
#     File: Colin_Powell_0187.jpg
#     File: Colin_Powell_0053.jpg
#     File: Colin_Powell_0098.jpg
#     File: Colin_Powell_0217.jpg
#     File: Colin_Powell_0109.jpg
#     File: Colin_Powell_0046.jpg
#     File: Colin_Powell_0184.jpg
#     File: Colin_Powell_0124.jpg
#     File: Colin_Powell_0198.jpg
#     File: Colin_Powell_0128.jpg
#     File: Colin_Powell_0157.jpg
#     File: Colin_Powell_0069.jpg
#     File: Colin_Powell_0030.jpg
#     File: Colin_Powell_0168.jpg
#     File: Colin_Powell_0171.jpg
#     File: Colin_Powell_0191.jpg
#     File: Colin_Powell_0131.jpg
#     File: Colin_Powell_0050.jpg
#     File: Colin_Powell_0146.jpg
#     File: Colin_Powell_0233.jpg
#     File: Colin_Powell_0154.jpg
#     File: Colin_Powell_0115.jpg
#     File: Colin_Powell_0119.jpg
#     File: Colin_Powell_0202.jpg
#     File: Colin_Powell_0213.jpg
#   Folder: Mian_Khursheed_Mehmood_Kasuri
#     File: Mian_Khursheed_Mehmood_Kasuri_0001.jpg
#     File: Mian_Khursheed_Mehmood_Kasuri_0002.jpg
#     File: Mian_Khursheed_Mehmood_Kasuri_0004.jpg
#     File: Mian_Khursheed_Mehmood_Kasuri_0003.jpg
#   Folder: Woody_Allen
#     File: Woody_Allen_0004.jpg
#     File: Woody_Allen_0001.jpg
#     File: Woody_Allen_0003.jpg
#     File: Woody_Allen_0002.jpg
#     File: Woody_Allen_0005.jpg
#   Folder: Imran_Khan
#     File: Imran_Khan_0001.jpg
#   Folder: Stan_Heath
#     File: Stan_Heath_0002.jpg
#     File: Stan_Heath_0001.jpg
#   Folder: Gabriel_Farhi
#     File: Gabriel_Farhi_0001.jpg
#   Folder: Larry_Donald
#     File: Larry_Donald_0001.jpg
#   Folder: Matthew_Broderick
#     File: Matthew_Broderick_0001.jpg
#     File: Matthew_Broderick_0002.jpg
#     File: Matthew_Broderick_0003.jpg
#     File: Matthew_Broderick_0004.jpg
#   Folder: Alejandro_Gonzalez_Inarritu
#     File: Alejandro_Gonzalez_Inarritu_0001.jpg
#   Folder: Brenda_Magana
#     File: Brenda_Magana_0001.jpg
#   Folder: Jose_Vicente_Rangel
#     File: Jose_Vicente_Rangel_0001.jpg
#   Folder: Giancarlo_Fisichella
#     File: Giancarlo_Fisichella_0001.jpg
#   Folder: Tammy_Helm
#     File: Tammy_Helm_0001.jpg
#   Folder: Francois_Ozon
#     File: Francois_Ozon_0001.jpg
#   Folder: William_Genego
#     File: William_Genego_0001.jpg
#   Folder: Marianne_Stanley
#     File: Marianne_Stanley_0001.jpg
#   Folder: Abdel_Aziz_Al-Hakim
#     File: Abdel_Aziz_Al-Hakim_0001.jpg
#   Folder: Brad_Brownell
#     File: Brad_Brownell_0001.jpg
#   Folder: Jeri_Ryan
#     File: Jeri_Ryan_0001.jpg
#   Folder: Margaret_Hasley
#     File: Margaret_Hasley_0001.jpg
#   Folder: Patty_Sheehan
#     File: Patty_Sheehan_0001.jpg
#   Folder: Tim_Allen
#     File: Tim_Allen_0004.jpg
#     File: Tim_Allen_0002.jpg
#     File: Tim_Allen_0003.jpg
#     File: Tim_Allen_0001.jpg
#   Folder: Augusto_Pinochet
#     File: Augusto_Pinochet_0002.jpg
#     File: Augusto_Pinochet_0001.jpg
#   Folder: Emmanuel_Milingo
#     File: Emmanuel_Milingo_0001.jpg
#   Folder: Steve_Cutler
#     File: Steve_Cutler_0001.jpg
#   Folder: Mark_Rosenbaum
#     File: Mark_Rosenbaum_0001.jpg
#   Folder: Alain_Ducasse
#     File: Alain_Ducasse_0001.jpg
#   Folder: Babe_Ruth
#     File: Babe_Ruth_0001.jpg
#   Folder: Sachiko_Yamada
#     File: Sachiko_Yamada_0002.jpg
#     File: Sachiko_Yamada_0003.jpg
#     File: Sachiko_Yamada_0004.jpg
#     File: Sachiko_Yamada_0001.jpg
#   Folder: Raja_Ramani
#     File: Raja_Ramani_0001.jpg
#   Folder: Esther_Macklin
#     File: Esther_Macklin_0001.jpg
#   Folder: Jamling_Norgay
#     File: Jamling_Norgay_0002.jpg
#     File: Jamling_Norgay_0001.jpg
#   Folder: Paul_Brandt
#     File: Paul_Brandt_0001.jpg
#   Folder: Valentina_Tereshkova
#     File: Valentina_Tereshkova_0001.jpg
#   Folder: Paul_Gascoigne
#     File: Paul_Gascoigne_0002.jpg
#     File: Paul_Gascoigne_0001.jpg
#     File: Paul_Gascoigne_0003.jpg
#   Folder: Richard_Myers
#     File: Richard_Myers_0016.jpg
#     File: Richard_Myers_0006.jpg
#     File: Richard_Myers_0011.jpg
#     File: Richard_Myers_0015.jpg
#     File: Richard_Myers_0013.jpg
#     File: Richard_Myers_0003.jpg
#     File: Richard_Myers_0014.jpg
#     File: Richard_Myers_0012.jpg
#     File: Richard_Myers_0004.jpg
#     File: Richard_Myers_0008.jpg
#     File: Richard_Myers_0001.jpg
#     File: Richard_Myers_0002.jpg
#     File: Richard_Myers_0010.jpg
#     File: Richard_Myers_0017.jpg
#     File: Richard_Myers_0009.jpg
#     File: Richard_Myers_0018.jpg
#     File: Richard_Myers_0005.jpg
#     File: Richard_Myers_0007.jpg
#   Folder: Josh_Evans
#     File: Josh_Evans_0001.jpg
#   Folder: Gus_Frerotte
#     File: Gus_Frerotte_0001.jpg
#   Folder: Alberto_Gonzales
#     File: Alberto_Gonzales_0001.jpg
#   Folder: Joseph_Salgado
#     File: Joseph_Salgado_0001.jpg
#   Folder: Bill_Graham
#     File: Bill_Graham_0009.jpg
#     File: Bill_Graham_0002.jpg
#     File: Bill_Graham_0005.jpg
#     File: Bill_Graham_0008.jpg
#     File: Bill_Graham_0003.jpg
#     File: Bill_Graham_0001.jpg
#     File: Bill_Graham_0007.jpg
#     File: Bill_Graham_0004.jpg
#     File: Bill_Graham_0006.jpg
#   Folder: Marieta_Chrousala
#     File: Marieta_Chrousala_0001.jpg
#     File: Marieta_Chrousala_0003.jpg
#     File: Marieta_Chrousala_0002.jpg
#   Folder: Walter_Annenberg
#     File: Walter_Annenberg_0001.jpg
#   Folder: Billy_Rork
#     File: Billy_Rork_0001.jpg
#   Folder: Jamie_Kellner
#     File: Jamie_Kellner_0001.jpg
#   Folder: Ilan_Ramon
#     File: Ilan_Ramon_0002.jpg
#     File: Ilan_Ramon_0001.jpg
#     File: Ilan_Ramon_0003.jpg
#   Folder: Gary_Coleman
#     File: Gary_Coleman_0001.jpg
#   Folder: Zach_Safrin
#     File: Zach_Safrin_0001.jpg
#   Folder: Bill_Self
#     File: Bill_Self_0001.jpg
#   Folder: Hee-Won_Han
#     File: Hee-Won_Han_0003.jpg
#     File: Hee-Won_Han_0002.jpg
#     File: Hee-Won_Han_0001.jpg
#   Folder: Paula_Abdul
#     File: Paula_Abdul_0001.jpg
#   Folder: Erik_Morales
#     File: Erik_Morales_0003.jpg
#     File: Erik_Morales_0001.jpg
#     File: Erik_Morales_0002.jpg
#   Folder: John_White
#     File: John_White_0001.jpg
#   Folder: Barry_Collier
#     File: Barry_Collier_0001.jpg
#   Folder: Rachel_Griffiths
#     File: Rachel_Griffiths_0002.jpg
#     File: Rachel_Griffiths_0003.jpg
#     File: Rachel_Griffiths_0001.jpg
#   Folder: Mohammad_Fares
#     File: Mohammad_Fares_0001.jpg
#   Folder: Dora_Bakoyianni
#     File: Dora_Bakoyianni_0001.jpg
#   Folder: Gustavo_Cisneros
#     File: Gustavo_Cisneros_0001.jpg
#   Folder: Tim_Curley
#     File: Tim_Curley_0001.jpg
#   Folder: Nia_Vardalos
#     File: Nia_Vardalos_0003.jpg
#     File: Nia_Vardalos_0004.jpg
#     File: Nia_Vardalos_0005.jpg
#     File: Nia_Vardalos_0002.jpg
#     File: Nia_Vardalos_0001.jpg
#   Folder: Richard_Reid
#     File: Richard_Reid_0001.jpg
#   Folder: Lisa_Girman
#     File: Lisa_Girman_0001.jpg
#   Folder: Paddy_Long
#     File: Paddy_Long_0001.jpg
#   Folder: Kim_Jong-Il
#     File: Kim_Jong-Il_0002.jpg
#     File: Kim_Jong-Il_0001.jpg
#     File: Kim_Jong-Il_0003.jpg
#     File: Kim_Jong-Il_0004.jpg
#   Folder: Carlton_Dotson
#     File: Carlton_Dotson_0001.jpg
#   Folder: Denise_Locke
#     File: Denise_Locke_0001.jpg
#   Folder: Damon_Dash
#     File: Damon_Dash_0001.jpg
#   Folder: Jennifer_Thompson
#     File: Jennifer_Thompson_0001.jpg
#     File: Jennifer_Thompson_0002.jpg
#   Folder: Lane_Bryant
#     File: Lane_Bryant_0001.jpg
#   Folder: Morris_Watts
#     File: Morris_Watts_0001.jpg
#   Folder: Tara_Kirk
#     File: Tara_Kirk_0001.jpg
#   Folder: Joe_Plumeri
#     File: Joe_Plumeri_0001.jpg
#   Folder: Akiko_Morigami
#     File: Akiko_Morigami_0001.jpg
#   Folder: Jessica_Alba
#     File: Jessica_Alba_0001.jpg
#     File: Jessica_Alba_0002.jpg
#   Folder: Mike_Miller
#     File: Mike_Miller_0001.jpg
#     File: Mike_Miller_0002.jpg
#   Folder: Rafidah_Aziz
#     File: Rafidah_Aziz_0001.jpg
#   Folder: Nicholoas_DiMarzio
#     File: Nicholoas_DiMarzio_0001.jpg
#   Folder: Qazi_Afzal
#     File: Qazi_Afzal_0001.jpg
#   Folder: Donald_Evans
#     File: Donald_Evans_0001.jpg
#     File: Donald_Evans_0002.jpg
#   Folder: Chok_Tong_Goh
#     File: Chok_Tong_Goh_0002.jpg
#     File: Chok_Tong_Goh_0001.jpg
#   Folder: Juliette_Binoche
#     File: Juliette_Binoche_0001.jpg
#   Folder: Jaromir_Jagr
#     File: Jaromir_Jagr_0001.jpg
#   Folder: TJ_Ford
#     File: TJ_Ford_0001.jpg
#   Folder: Adrian_Fernandez
#     File: Adrian_Fernandez_0001.jpg
#   Folder: David_Siegel
#     File: David_Siegel_0001.jpg
#   Folder: Vanessa_Williams
#     File: Vanessa_Williams_0003.jpg
#     File: Vanessa_Williams_0002.jpg
#     File: Vanessa_Williams_0001.jpg
#   Folder: Tiffany_Limos
#     File: Tiffany_Limos_0001.jpg
#   Folder: Federico_Trillo
#     File: Federico_Trillo_0001.jpg
#     File: Federico_Trillo_0002.jpg
#     File: Federico_Trillo_0003.jpg
#   Folder: Mary_Tyler_Moore
#     File: Mary_Tyler_Moore_0001.jpg
#     File: Mary_Tyler_Moore_0002.jpg
#   Folder: Andy_Garcia
#     File: Andy_Garcia_0001.jpg
#   Folder: John_Herrington
#     File: John_Herrington_0001.jpg
#   Folder: Anil_Ramsook
#     File: Anil_Ramsook_0001.jpg
#   Folder: Kate_Moss
#     File: Kate_Moss_0001.jpg
#   Folder: Kevin_Harvick
#     File: Kevin_Harvick_0001.jpg
#   Folder: Anibal_Ibarra
#     File: Anibal_Ibarra_0001.jpg
#     File: Anibal_Ibarra_0002.jpg
#     File: Anibal_Ibarra_0003.jpg
#   Folder: Sheila_Fraser
#     File: Sheila_Fraser_0001.jpg
#     File: Sheila_Fraser_0002.jpg
#   Folder: Holly_Hunter
#     File: Holly_Hunter_0005.jpg
#     File: Holly_Hunter_0007.jpg
#     File: Holly_Hunter_0002.jpg
#     File: Holly_Hunter_0006.jpg
#     File: Holly_Hunter_0003.jpg
#     File: Holly_Hunter_0004.jpg
#     File: Holly_Hunter_0001.jpg
#   Folder: Khaled_Sawalhi
#     File: Khaled_Sawalhi_0001.jpg
#   Folder: Emma_Nicholson
#     File: Emma_Nicholson_0001.jpg
#   Folder: Habib_Hisham
#     File: Habib_Hisham_0001.jpg
#   Folder: Rohinton_Mistry
#     File: Rohinton_Mistry_0001.jpg
#   Folder: Louis_Van_Gaal
#     File: Louis_Van_Gaal_0001.jpg
#   Folder: Wycliffe_Grousbeck
#     File: Wycliffe_Grousbeck_0001.jpg
#   Folder: Daryl_Jones
#     File: Daryl_Jones_0001.jpg
#   Folder: Joe_Mendes
#     File: Joe_Mendes_0001.jpg
#   Folder: Ruano_Pascual
#     File: Ruano_Pascual_0001.jpg
#   Folder: Erika_Reyes
#     File: Erika_Reyes_0001.jpg
#   Folder: Koji_Uehara
#     File: Koji_Uehara_0001.jpg
#   Folder: Noer_Moeis
#     File: Noer_Moeis_0001.jpg
#   Folder: Andrea_De_Cruz
#     File: Andrea_De_Cruz_0001.jpg
#   Folder: Wanda_Ilene_Barzee
#     File: Wanda_Ilene_Barzee_0001.jpg
#   Folder: Colin_Cowie
#     File: Colin_Cowie_0001.jpg
#   Folder: Betsy_Smith
#     File: Betsy_Smith_0001.jpg
#     File: Betsy_Smith_0002.jpg
#   Folder: Landon_Donovan
#     File: Landon_Donovan_0001.jpg
#   Folder: Maria_Shkolnikova
#     File: Maria_Shkolnikova_0001.jpg
#   Folder: Tim_Pawlenty
#     File: Tim_Pawlenty_0001.jpg
#   Folder: Larry_Beinfest
#     File: Larry_Beinfest_0001.jpg
#   Folder: Xiang_Liu
#     File: Xiang_Liu_0001.jpg
#   Folder: Richard_Jefferson
#     File: Richard_Jefferson_0001.jpg
#   Folder: Taufik_Kiemas
#     File: Taufik_Kiemas_0001.jpg
#   Folder: Alexandra_Rozovskaya
#     File: Alexandra_Rozovskaya_0001.jpg
#   Folder: Howard_Stringer
#     File: Howard_Stringer_0001.jpg
#   Folder: Silvia_Farina_Elia
#     File: Silvia_Farina_Elia_0003.jpg
#     File: Silvia_Farina_Elia_0002.jpg
#     File: Silvia_Farina_Elia_0001.jpg
#   Folder: Billy_Edelin
#     File: Billy_Edelin_0001.jpg
#   Folder: Tom_Cruise
#     File: Tom_Cruise_0002.jpg
#     File: Tom_Cruise_0009.jpg
#     File: Tom_Cruise_0004.jpg
#     File: Tom_Cruise_0005.jpg
#     File: Tom_Cruise_0001.jpg
#     File: Tom_Cruise_0007.jpg
#     File: Tom_Cruise_0003.jpg
#     File: Tom_Cruise_0010.jpg
#     File: Tom_Cruise_0008.jpg
#     File: Tom_Cruise_0006.jpg
#   Folder: Will_Ofenheusle
#     File: Will_Ofenheusle_0001.jpg
#   Folder: James_Ivory
#     File: James_Ivory_0002.jpg
#     File: James_Ivory_0001.jpg
#   Folder: Vinnie_Jones
#     File: Vinnie_Jones_0001.jpg
#   Folder: Chadha_Gurinder
#     File: Chadha_Gurinder_0001.jpg
#   Folder: Craig_Wilson
#     File: Craig_Wilson_0001.jpg
#   Folder: William_Burns
#     File: William_Burns_0002.jpg
#     File: William_Burns_0001.jpg
#   Folder: Joe_Finley
#     File: Joe_Finley_0001.jpg
#   Folder: Joey_Mantia
#     File: Joey_Mantia_0001.jpg
#   Folder: Hugo_Chavez
#     File: Hugo_Chavez_0061.jpg
#     File: Hugo_Chavez_0018.jpg
#     File: Hugo_Chavez_0057.jpg
#     File: Hugo_Chavez_0024.jpg
#     File: Hugo_Chavez_0001.jpg
#     File: Hugo_Chavez_0019.jpg
#     File: Hugo_Chavez_0041.jpg
#     File: Hugo_Chavez_0027.jpg
#     File: Hugo_Chavez_0062.jpg
#     File: Hugo_Chavez_0006.jpg
#     File: Hugo_Chavez_0050.jpg
#     File: Hugo_Chavez_0040.jpg
#     File: Hugo_Chavez_0023.jpg
#     File: Hugo_Chavez_0026.jpg
#     File: Hugo_Chavez_0064.jpg
#     File: Hugo_Chavez_0065.jpg
#     File: Hugo_Chavez_0036.jpg
#     File: Hugo_Chavez_0067.jpg
#     File: Hugo_Chavez_0052.jpg
#     File: Hugo_Chavez_0029.jpg
#     File: Hugo_Chavez_0005.jpg
#     File: Hugo_Chavez_0048.jpg
#     File: Hugo_Chavez_0025.jpg
#     File: Hugo_Chavez_0032.jpg
#     File: Hugo_Chavez_0055.jpg
#     File: Hugo_Chavez_0031.jpg
#     File: Hugo_Chavez_0016.jpg
#     File: Hugo_Chavez_0035.jpg
#     File: Hugo_Chavez_0004.jpg
#     File: Hugo_Chavez_0014.jpg
#     File: Hugo_Chavez_0017.jpg
#     File: Hugo_Chavez_0044.jpg
#     File: Hugo_Chavez_0037.jpg
#     File: Hugo_Chavez_0047.jpg
#     File: Hugo_Chavez_0028.jpg
#     File: Hugo_Chavez_0020.jpg
#     File: Hugo_Chavez_0011.jpg
#     File: Hugo_Chavez_0058.jpg
#     File: Hugo_Chavez_0012.jpg
#     File: Hugo_Chavez_0015.jpg
#     File: Hugo_Chavez_0060.jpg
#     File: Hugo_Chavez_0022.jpg
#     File: Hugo_Chavez_0002.jpg
#     File: Hugo_Chavez_0042.jpg
#     File: Hugo_Chavez_0068.jpg
#     File: Hugo_Chavez_0043.jpg
#     File: Hugo_Chavez_0059.jpg
#     File: Hugo_Chavez_0045.jpg
#     File: Hugo_Chavez_0039.jpg
#     File: Hugo_Chavez_0070.jpg
#     File: Hugo_Chavez_0054.jpg
#     File: Hugo_Chavez_0030.jpg
#     File: Hugo_Chavez_0056.jpg
#     File: Hugo_Chavez_0010.jpg
#     File: Hugo_Chavez_0051.jpg
#     File: Hugo_Chavez_0007.jpg
#     File: Hugo_Chavez_0009.jpg
#     File: Hugo_Chavez_0034.jpg
#     File: Hugo_Chavez_0013.jpg
#     File: Hugo_Chavez_0021.jpg
#     File: Hugo_Chavez_0003.jpg
#     File: Hugo_Chavez_0053.jpg
#     File: Hugo_Chavez_0069.jpg
#     File: Hugo_Chavez_0066.jpg
#     File: Hugo_Chavez_0049.jpg
#     File: Hugo_Chavez_0063.jpg
#     File: Hugo_Chavez_0046.jpg
#     File: Hugo_Chavez_0033.jpg
#     File: Hugo_Chavez_0008.jpg
#     File: Hugo_Chavez_0038.jpg
#     File: Hugo_Chavez_0071.jpg
#   Folder: Steve_Stirling
#     File: Steve_Stirling_0001.jpg
#   Folder: Steffeny_Holtz
#     File: Steffeny_Holtz_0001.jpg
#   Folder: Jerry_Seinfeld
#     File: Jerry_Seinfeld_0001.jpg
#   Folder: Tim_Conway
#     File: Tim_Conway_0003.jpg
#     File: Tim_Conway_0002.jpg
#     File: Tim_Conway_0001.jpg
#   Folder: Mariana_Ohata
#     File: Mariana_Ohata_0001.jpg
#   Folder: Demetrius_Ferraciu
#     File: Demetrius_Ferraciu_0001.jpg
#     File: Demetrius_Ferraciu_0002.jpg
#   Folder: Jeanne_Anne_Schroeder
#     File: Jeanne_Anne_Schroeder_0001.jpg
#   Folder: Jana_Henke
#     File: Jana_Henke_0001.jpg
#   Folder: Kirsten_Clark
#     File: Kirsten_Clark_0001.jpg
#   Folder: Martin_Howard
#     File: Martin_Howard_0001.jpg
#   Folder: David_Stern
#     File: David_Stern_0004.jpg
#     File: David_Stern_0003.jpg
#     File: David_Stern_0001.jpg
#     File: David_Stern_0002.jpg
#   Folder: Jane_Riley
#     File: Jane_Riley_0001.jpg
#   Folder: Jim_Piper
#     File: Jim_Piper_0001.jpg
#   Folder: Michael_Lopez-Alegria
#     File: Michael_Lopez-Alegria_0001.jpg
#   Folder: Jon_Voight
#     File: Jon_Voight_0001.jpg
#     File: Jon_Voight_0003.jpg
#     File: Jon_Voight_0002.jpg
#   Folder: Wayne_Ferreira
#     File: Wayne_Ferreira_0004.jpg
#     File: Wayne_Ferreira_0003.jpg
#     File: Wayne_Ferreira_0005.jpg
#     File: Wayne_Ferreira_0001.jpg
#     File: Wayne_Ferreira_0002.jpg
#   Folder: Ralph_Friedgen
#     File: Ralph_Friedgen_0001.jpg
#   Folder: Ashley_Judd
#     File: Ashley_Judd_0001.jpg
#   Folder: Brian_De_Palma
#     File: Brian_De_Palma_0001.jpg
#   Folder: Mike_Price
#     File: Mike_Price_0002.jpg
#     File: Mike_Price_0001.jpg
#   Folder: Steny_Hoyer
#     File: Steny_Hoyer_0001.jpg
#   Folder: Qazi_Hussain_Ahmed
#     File: Qazi_Hussain_Ahmed_0001.jpg
#   Folder: Ross_Verba
#     File: Ross_Verba_0001.jpg
#   Folder: Christian_Malcolm
#     File: Christian_Malcolm_0001.jpg
#   Folder: Christian_Lacroix
#     File: Christian_Lacroix_0001.jpg
#   Folder: Steve_Lenard
#     File: Steve_Lenard_0001.jpg
#   Folder: Lloyd_Mudiwa
#     File: Lloyd_Mudiwa_0001.jpg
#   Folder: Roger_Etchegaray
#     File: Roger_Etchegaray_0001.jpg
#   Folder: Annie_Chaplin
#     File: Annie_Chaplin_0001.jpg
#   Folder: Ben_Cahoon
#     File: Ben_Cahoon_0001.jpg
#   Folder: Thomas_Weston
#     File: Thomas_Weston_0001.jpg
#   Folder: Abdullah_Ahmad_Badawi
#     File: Abdullah_Ahmad_Badawi_0001.jpg
#   Folder: Jay_Garner
#     File: Jay_Garner_0002.jpg
#     File: Jay_Garner_0005.jpg
#     File: Jay_Garner_0006.jpg
#     File: Jay_Garner_0003.jpg
#     File: Jay_Garner_0004.jpg
#     File: Jay_Garner_0001.jpg
#   Folder: Bruna_Colosio
#     File: Bruna_Colosio_0001.jpg
#   Folder: Bustam_A_Zedan_Aljanabi
#     File: Bustam_A_Zedan_Aljanabi_0001.jpg
#   Folder: Vidar_Helgesen
#     File: Vidar_Helgesen_0001.jpg
#     File: Vidar_Helgesen_0002.jpg
#   Folder: Ray_Morrough
#     File: Ray_Morrough_0001.jpg
#   Folder: Giulio_Andreotti
#     File: Giulio_Andreotti_0001.jpg
#   Folder: Goran_Zivkovic
#     File: Goran_Zivkovic_0001.jpg
#   Folder: Vin_Diesel
#     File: Vin_Diesel_0002.jpg
#     File: Vin_Diesel_0001.jpg
#   Folder: Ozzy_Osbourne
#     File: Ozzy_Osbourne_0003.jpg
#     File: Ozzy_Osbourne_0002.jpg
#     File: Ozzy_Osbourne_0001.jpg
#   Folder: Andy_Rooney
#     File: Andy_Rooney_0001.jpg
#   Folder: Jean-Claude_Van_Damme
#     File: Jean-Claude_Van_Damme_0001.jpg
#   Folder: Mark_Lazarus
#     File: Mark_Lazarus_0001.jpg
#   Folder: Queen_Beatrix
#     File: Queen_Beatrix_0002.jpg
#     File: Queen_Beatrix_0003.jpg
#     File: Queen_Beatrix_0001.jpg
#     File: Queen_Beatrix_0004.jpg
#   Folder: Abdul_Rahman
#     File: Abdul_Rahman_0001.jpg
#   Folder: David_Caraway
#     File: David_Caraway_0001.jpg
#     File: David_Caraway_0002.jpg
#   Folder: Tom_Miller
#     File: Tom_Miller_0001.jpg
#   Folder: Mohammed_Mehdi_Saleh
#     File: Mohammed_Mehdi_Saleh_0001.jpg
#   Folder: Miranda_Gaddis
#     File: Miranda_Gaddis_0001.jpg
#   Folder: Gustavo_Franco
#     File: Gustavo_Franco_0001.jpg
#   Folder: John_Cornyn
#     File: John_Cornyn_0001.jpg
#   Folder: Michael_Winterbottom
#     File: Michael_Winterbottom_0002.jpg
#     File: Michael_Winterbottom_0003.jpg
#     File: Michael_Winterbottom_0001.jpg
#   Folder: Jason_Mewes
#     File: Jason_Mewes_0001.jpg
#   Folder: Mahathir_Mohamad
#     File: Mahathir_Mohamad_0006.jpg
#     File: Mahathir_Mohamad_0005.jpg
#     File: Mahathir_Mohamad_0002.jpg
#     File: Mahathir_Mohamad_0008.jpg
#     File: Mahathir_Mohamad_0014.jpg
#     File: Mahathir_Mohamad_0004.jpg
#     File: Mahathir_Mohamad_0003.jpg
#     File: Mahathir_Mohamad_0009.jpg
#     File: Mahathir_Mohamad_0011.jpg
#     File: Mahathir_Mohamad_0001.jpg
#     File: Mahathir_Mohamad_0012.jpg
#     File: Mahathir_Mohamad_0010.jpg
#     File: Mahathir_Mohamad_0013.jpg
#     File: Mahathir_Mohamad_0007.jpg
#   Folder: JK_Rowling
#     File: JK_Rowling_0001.jpg
#     File: JK_Rowling_0004.jpg
#     File: JK_Rowling_0005.jpg
#     File: JK_Rowling_0003.jpg
#     File: JK_Rowling_0006.jpg
#     File: JK_Rowling_0002.jpg
#   Folder: Marie_Haghal
#     File: Marie_Haghal_0001.jpg
#   Folder: Norodom_Chakrapong
#     File: Norodom_Chakrapong_0001.jpg
#   Folder: Felipe_De_Borbon
#     File: Felipe_De_Borbon_0001.jpg
#   Folder: Minnie_Driver
#     File: Minnie_Driver_0001.jpg
#     File: Minnie_Driver_0002.jpg
#   Folder: Eduardo_Fischer
#     File: Eduardo_Fischer_0001.jpg
#   Folder: Chloe_Sevigny
#     File: Chloe_Sevigny_0001.jpg
#   Folder: Patrick_Clawsen
#     File: Patrick_Clawsen_0001.jpg
#   Folder: Se_Hyuk_Joo
#     File: Se_Hyuk_Joo_0001.jpg
#   Folder: Dominick_Dunne
#     File: Dominick_Dunne_0001.jpg
#   Folder: Wesley_Clark
#     File: Wesley_Clark_0002.jpg
#     File: Wesley_Clark_0001.jpg
#   Folder: Sammy_Sosa
#     File: Sammy_Sosa_0002.jpg
#     File: Sammy_Sosa_0001.jpg
#   Folder: Vince_Dooley
#     File: Vince_Dooley_0001.jpg
#   Folder: Janine_Pietsch
#     File: Janine_Pietsch_0001.jpg
#   Folder: Talisa_Bratt
#     File: Talisa_Bratt_0001.jpg
#   Folder: Daniele_Hypolito
#     File: Daniele_Hypolito_0001.jpg
#   Folder: Audrey_Sauret
#     File: Audrey_Sauret_0001.jpg
#   Folder: Dionigi_Tettamanzi
#     File: Dionigi_Tettamanzi_0001.jpg
#   Folder: Luis_Pujols
#     File: Luis_Pujols_0001.jpg
#   Folder: William_Hurt
#     File: William_Hurt_0001.jpg
#   Folder: Charlie_Zaa
#     File: Charlie_Zaa_0001.jpg
#     File: Charlie_Zaa_0002.jpg
#   Folder: Andy_North
#     File: Andy_North_0001.jpg
#   Folder: Cathy_Freeman
#     File: Cathy_Freeman_0002.jpg
#     File: Cathy_Freeman_0001.jpg
#   Folder: Michelle_Collins
#     File: Michelle_Collins_0002.jpg
#     File: Michelle_Collins_0001.jpg
#   Folder: James_Cunningham
#     File: James_Cunningham_0002.jpg
#     File: James_Cunningham_0001.jpg
#     File: James_Cunningham_0003.jpg
#   Folder: Khum_Bahadur_Khadka
#     File: Khum_Bahadur_Khadka_0001.jpg
#   Folder: Isabel_Orellana
#     File: Isabel_Orellana_0001.jpg
#   Folder: Armand_Sargen
#     File: Armand_Sargen_0001.jpg
#   Folder: Marc_Shaiman
#     File: Marc_Shaiman_0001.jpg
#   Folder: Catherine_Woodard
#     File: Catherine_Woodard_0001.jpg
#   Folder: Jeremy_Greenstock
#     File: Jeremy_Greenstock_0010.jpg
#     File: Jeremy_Greenstock_0002.jpg
#     File: Jeremy_Greenstock_0009.jpg
#     File: Jeremy_Greenstock_0006.jpg
#     File: Jeremy_Greenstock_0019.jpg
#     File: Jeremy_Greenstock_0001.jpg
#     File: Jeremy_Greenstock_0017.jpg
#     File: Jeremy_Greenstock_0007.jpg
#     File: Jeremy_Greenstock_0011.jpg
#     File: Jeremy_Greenstock_0024.jpg
#     File: Jeremy_Greenstock_0016.jpg
#     File: Jeremy_Greenstock_0003.jpg
#     File: Jeremy_Greenstock_0022.jpg
#     File: Jeremy_Greenstock_0021.jpg
#     File: Jeremy_Greenstock_0014.jpg
#     File: Jeremy_Greenstock_0023.jpg
#     File: Jeremy_Greenstock_0008.jpg
#     File: Jeremy_Greenstock_0015.jpg
#     File: Jeremy_Greenstock_0013.jpg
#     File: Jeremy_Greenstock_0012.jpg
#     File: Jeremy_Greenstock_0018.jpg
#     File: Jeremy_Greenstock_0005.jpg
#     File: Jeremy_Greenstock_0020.jpg
#     File: Jeremy_Greenstock_0004.jpg
#   Folder: Ham_Pong-sil
#     File: Ham_Pong-sil_0001.jpg
#   Folder: Vaclav_Havel
#     File: Vaclav_Havel_0009.jpg
#     File: Vaclav_Havel_0005.jpg
#     File: Vaclav_Havel_0004.jpg
#     File: Vaclav_Havel_0001.jpg
#     File: Vaclav_Havel_0006.jpg
#     File: Vaclav_Havel_0003.jpg
#     File: Vaclav_Havel_0008.jpg
#     File: Vaclav_Havel_0002.jpg
#     File: Vaclav_Havel_0007.jpg
#   Folder: Daniel_Montenegro
#     File: Daniel_Montenegro_0001.jpg
#   Folder: Sharon_Robinson
#     File: Sharon_Robinson_0001.jpg
#   Folder: Rubens_Barrichello
#     File: Rubens_Barrichello_0007.jpg
#     File: Rubens_Barrichello_0009.jpg
#     File: Rubens_Barrichello_0005.jpg
#     File: Rubens_Barrichello_0003.jpg
#     File: Rubens_Barrichello_0006.jpg
#     File: Rubens_Barrichello_0004.jpg
#     File: Rubens_Barrichello_0011.jpg
#     File: Rubens_Barrichello_0001.jpg
#     File: Rubens_Barrichello_0010.jpg
#     File: Rubens_Barrichello_0012.jpg
#     File: Rubens_Barrichello_0008.jpg
#     File: Rubens_Barrichello_0002.jpg
#   Folder: Stephan_Eberharter
#     File: Stephan_Eberharter_0001.jpg
#   Folder: Sheila_Taormina
#     File: Sheila_Taormina_0001.jpg
#   Folder: Eva_Herzigova
#     File: Eva_Herzigova_0001.jpg
#   Folder: Eduardo_Duhalde
#     File: Eduardo_Duhalde_0006.jpg
#     File: Eduardo_Duhalde_0011.jpg
#     File: Eduardo_Duhalde_0008.jpg
#     File: Eduardo_Duhalde_0003.jpg
#     File: Eduardo_Duhalde_0013.jpg
#     File: Eduardo_Duhalde_0004.jpg
#     File: Eduardo_Duhalde_0012.jpg
#     File: Eduardo_Duhalde_0005.jpg
#     File: Eduardo_Duhalde_0002.jpg
#     File: Eduardo_Duhalde_0007.jpg
#     File: Eduardo_Duhalde_0014.jpg
#     File: Eduardo_Duhalde_0009.jpg
#     File: Eduardo_Duhalde_0010.jpg
#     File: Eduardo_Duhalde_0001.jpg
#   Folder: Talisa_Soto
#     File: Talisa_Soto_0001.jpg
#   Folder: Ashley_Olsen
#     File: Ashley_Olsen_0001.jpg
#   Folder: Jan_Petersen
#     File: Jan_Petersen_0001.jpg
#   Folder: Jason_Petty
#     File: Jason_Petty_0001.jpg
#   Folder: Mufti_Mohammad_Syed
#     File: Mufti_Mohammad_Syed_0001.jpg
#   Folder: Chyung_Dai-chul
#     File: Chyung_Dai-chul_0001.jpg
#   Folder: Darrell_Porter
#     File: Darrell_Porter_0002.jpg
#     File: Darrell_Porter_0001.jpg
#   Folder: William_Rehnquist
#     File: William_Rehnquist_0002.jpg
#     File: William_Rehnquist_0001.jpg
#   Folder: Javier_Solana
#     File: Javier_Solana_0001.jpg
#     File: Javier_Solana_0008.jpg
#     File: Javier_Solana_0007.jpg
#     File: Javier_Solana_0002.jpg
#     File: Javier_Solana_0004.jpg
#     File: Javier_Solana_0006.jpg
#     File: Javier_Solana_0005.jpg
#     File: Javier_Solana_0010.jpg
#     File: Javier_Solana_0009.jpg
#     File: Javier_Solana_0003.jpg
#   Folder: Jose_Santos
#     File: Jose_Santos_0001.jpg
#   Folder: Diana_Renee_Valdivieso_Dubon
#     File: Diana_Renee_Valdivieso_Dubon_0001.jpg
#   Folder: Troy_Jenkins
#     File: Troy_Jenkins_0001.jpg
#   Folder: Anthony_Pico
#     File: Anthony_Pico_0001.jpg
#   Folder: Richard_Crenna
#     File: Richard_Crenna_0001.jpg
#     File: Richard_Crenna_0002.jpg
#   Folder: Jacqueline_Gold
#     File: Jacqueline_Gold_0001.jpg
#   Folder: Danis_Tanovic
#     File: Danis_Tanovic_0001.jpg
#   Folder: Delphine_Chuillot
#     File: Delphine_Chuillot_0001.jpg
#   Folder: Sung_Hong_Choi
#     File: Sung_Hong_Choi_0001.jpg
#   Folder: Jeremy_Fogel
#     File: Jeremy_Fogel_0001.jpg
#   Folder: Mel_Brooks
#     File: Mel_Brooks_0001.jpg
#     File: Mel_Brooks_0002.jpg
#   Folder: Ashley_Postell
#     File: Ashley_Postell_0001.jpg
#   Folder: Jose_Genoino
#     File: Jose_Genoino_0001.jpg
#   Folder: Brawley_King
#     File: Brawley_King_0001.jpg
#   Folder: Edward_Egan
#     File: Edward_Egan_0001.jpg
#   Folder: Michael_Donovan
#     File: Michael_Donovan_0001.jpg
#   Folder: Johan_Bruyneel
#     File: Johan_Bruyneel_0001.jpg
#   Folder: Kevin_Stallings
#     File: Kevin_Stallings_0001.jpg
#     File: Kevin_Stallings_0002.jpg
#   Folder: Jacques_Kallis
#     File: Jacques_Kallis_0001.jpg
#   Folder: Olympia_Dukakis
#     File: Olympia_Dukakis_0001.jpg
#   Folder: Angelica_Romero
#     File: Angelica_Romero_0001.jpg
#   Folder: Karin_Pilsaeter
#     File: Karin_Pilsaeter_0001.jpg
#   Folder: Ron_Kirk
#     File: Ron_Kirk_0001.jpg
#   Folder: Robert_De_Niro
#     File: Robert_De_Niro_0006.jpg
#     File: Robert_De_Niro_0003.jpg
#     File: Robert_De_Niro_0001.jpg
#     File: Robert_De_Niro_0004.jpg
#     File: Robert_De_Niro_0005.jpg
#     File: Robert_De_Niro_0002.jpg
#   Folder: Alek_Wek
#     File: Alek_Wek_0001.jpg
#   Folder: Jeffery_Strelzin
#     File: Jeffery_Strelzin_0001.jpg
#   Folder: Uma_Thurman
#     File: Uma_Thurman_0001.jpg
#     File: Uma_Thurman_0002.jpg
#     File: Uma_Thurman_0003.jpg
#   Folder: Jan_Peter_Balkenende
#     File: Jan_Peter_Balkenende_0001.jpg
#   Folder: Melanie_Griffith
#     File: Melanie_Griffith_0003.jpg
#     File: Melanie_Griffith_0001.jpg
#     File: Melanie_Griffith_0002.jpg
#   Folder: Ernest_Hollings
#     File: Ernest_Hollings_0001.jpg
#   Folder: Ashraf_Alasmar
#     File: Ashraf_Alasmar_0001.jpg
#   Folder: Ismail_Abu_Shanab
#     File: Ismail_Abu_Shanab_0001.jpg
#   Folder: William_Webster
#     File: William_Webster_0001.jpg
#   Folder: Robert_Tyrrell
#     File: Robert_Tyrrell_0001.jpg
#   Folder: Craig_Doblin
#     File: Craig_Doblin_0001.jpg
#   Folder: Coco_dEste
#     File: Coco_dEste_0001.jpg
#   Folder: Carol_Moseley_Braun
#     File: Carol_Moseley_Braun_0002.jpg
#     File: Carol_Moseley_Braun_0001.jpg
#   Folder: Leigh_Winchell
#     File: Leigh_Winchell_0001.jpg
#   Folder: Greg_Owen
#     File: Greg_Owen_0001.jpg
#     File: Greg_Owen_0002.jpg
#   Folder: Thomas_Van_Essen
#     File: Thomas_Van_Essen_0001.jpg
#   Folder: Malcolm_Wild
#     File: Malcolm_Wild_0001.jpg
#   Folder: Richard_Levin
#     File: Richard_Levin_0001.jpg
#   Folder: Rafael_Vinoly
#     File: Rafael_Vinoly_0001.jpg
#   Folder: Ibrahim_Al-Marashi
#     File: Ibrahim_Al-Marashi_0001.jpg
#   Folder: John_Timoney
#     File: John_Timoney_0002.jpg
#     File: John_Timoney_0001.jpg
#   Folder: Marty_Mornhinweg
#     File: Marty_Mornhinweg_0002.jpg
#     File: Marty_Mornhinweg_0001.jpg
#     File: Marty_Mornhinweg_0003.jpg
#   Folder: Marwan_Muasher
#     File: Marwan_Muasher_0001.jpg
#   Folder: Nuon_Chea
#     File: Nuon_Chea_0001.jpg
#   Folder: Tian_Zhuang_Zhuang
#     File: Tian_Zhuang_Zhuang_0001.jpg
#   Folder: Mary_Zorn
#     File: Mary_Zorn_0001.jpg
#   Folder: Julio_Toro
#     File: Julio_Toro_0001.jpg
#   Folder: Mary_Steenburgen
#     File: Mary_Steenburgen_0002.jpg
#     File: Mary_Steenburgen_0003.jpg
#     File: Mary_Steenburgen_0001.jpg
#   Folder: Gloria_Trevi
#     File: Gloria_Trevi_0001.jpg
#     File: Gloria_Trevi_0002.jpg
#     File: Gloria_Trevi_0004.jpg
#     File: Gloria_Trevi_0003.jpg
#   Folder: Aaron_Pena
#     File: Aaron_Pena_0001.jpg
#   Folder: Fruit_Chan
#     File: Fruit_Chan_0001.jpg
#   Folder: Shigeru_Ishiba
#     File: Shigeru_Ishiba_0001.jpg
#   Folder: Robert_Marshall
#     File: Robert_Marshall_0001.jpg
#   Folder: Ronnie_Jagday
#     File: Ronnie_Jagday_0001.jpg
#   Folder: Jacqueline_Obradors
#     File: Jacqueline_Obradors_0002.jpg
#     File: Jacqueline_Obradors_0001.jpg
#   Folder: Jason_Jennings
#     File: Jason_Jennings_0002.jpg
#     File: Jason_Jennings_0001.jpg
#   Folder: Roger_Staubach
#     File: Roger_Staubach_0001.jpg
#   Folder: Abdel_Madi_Shabneh
#     File: Abdel_Madi_Shabneh_0001.jpg
#   Folder: Linda_Ham
#     File: Linda_Ham_0001.jpg
#   Folder: Damon_Stoudamire
#     File: Damon_Stoudamire_0001.jpg
#   Folder: Luciano_Bovicelli
#     File: Luciano_Bovicelli_0001.jpg
#   Folder: Andy_Madikians
#     File: Andy_Madikians_0001.jpg
#   Folder: Nancy_Powell
#     File: Nancy_Powell_0001.jpg
#   Folder: Stephane_Rochon
#     File: Stephane_Rochon_0001.jpg
#   Folder: Kenenisa_Bekele
#     File: Kenenisa_Bekele_0001.jpg
#   Folder: Jeff_Schiffner
#     File: Jeff_Schiffner_0001.jpg
#   Folder: Paul_Bettany
#     File: Paul_Bettany_0001.jpg
#   Folder: Al_Pacino
#     File: Al_Pacino_0002.jpg
#     File: Al_Pacino_0001.jpg
#     File: Al_Pacino_0003.jpg
#   Folder: Andrew_Gilligan
#     File: Andrew_Gilligan_0001.jpg
#   Folder: Richard_Gephardt
#     File: Richard_Gephardt_0010.jpg
#     File: Richard_Gephardt_0003.jpg
#     File: Richard_Gephardt_0011.jpg
#     File: Richard_Gephardt_0001.jpg
#     File: Richard_Gephardt_0005.jpg
#     File: Richard_Gephardt_0007.jpg
#     File: Richard_Gephardt_0009.jpg
#     File: Richard_Gephardt_0004.jpg
#     File: Richard_Gephardt_0006.jpg
#     File: Richard_Gephardt_0002.jpg
#     File: Richard_Gephardt_0008.jpg
#   Folder: Ed_Sullivan
#     File: Ed_Sullivan_0001.jpg
#   Folder: Michelle_Branch
#     File: Michelle_Branch_0002.jpg
#     File: Michelle_Branch_0001.jpg
#   Folder: Cemil_Cicek
#     File: Cemil_Cicek_0001.jpg
#   Folder: Alexander_Rumyantsev
#     File: Alexander_Rumyantsev_0001.jpg
#     File: Alexander_Rumyantsev_0002.jpg
#   Folder: Eminem
#     File: Eminem_0001.jpg
#   Folder: Dave_Odom
#     File: Dave_Odom_0001.jpg
#   Folder: Sarah_Michelle_Gellar
#     File: Sarah_Michelle_Gellar_0001.jpg
#     File: Sarah_Michelle_Gellar_0002.jpg
#     File: Sarah_Michelle_Gellar_0003.jpg
#   Folder: Chuck_Amato
#     File: Chuck_Amato_0001.jpg
#     File: Chuck_Amato_0002.jpg
#   Folder: Ethan_Hawke
#     File: Ethan_Hawke_0002.jpg
#     File: Ethan_Hawke_0004.jpg
#     File: Ethan_Hawke_0001.jpg
#     File: Ethan_Hawke_0003.jpg
#   Folder: Michael_Broad
#     File: Michael_Broad_0001.jpg
#   Folder: Raul_Chacon
#     File: Raul_Chacon_0001.jpg
#   Folder: Soon_Yi
#     File: Soon_Yi_0001.jpg
#   Folder: Sean_Astin
#     File: Sean_Astin_0001.jpg
#     File: Sean_Astin_0002.jpg
#     File: Sean_Astin_0003.jpg
#   Folder: Himmler_Rebu
#     File: Himmler_Rebu_0001.jpg
#   Folder: Matthew_McConaughey
#     File: Matthew_McConaughey_0001.jpg
#   Folder: Alexander_Payne
#     File: Alexander_Payne_0001.jpg
#   Folder: Festus_Mogae
#     File: Festus_Mogae_0001.jpg
#   Folder: Laura_Hernandez
#     File: Laura_Hernandez_0002.jpg
#     File: Laura_Hernandez_0001.jpg
#   Folder: Taku_Yamasaki
#     File: Taku_Yamasaki_0001.jpg
#   Folder: Mike_Smith
#     File: Mike_Smith_0001.jpg
#   Folder: John_Paul_II
#     File: John_Paul_II_0003.jpg
#     File: John_Paul_II_0005.jpg
#     File: John_Paul_II_0008.jpg
#     File: John_Paul_II_0002.jpg
#     File: John_Paul_II_0009.jpg
#     File: John_Paul_II_0006.jpg
#     File: John_Paul_II_0010.jpg
#     File: John_Paul_II_0001.jpg
#     File: John_Paul_II_0007.jpg
#     File: John_Paul_II_0011.jpg
#     File: John_Paul_II_0004.jpg
#   Folder: Marco_Pantani
#     File: Marco_Pantani_0001.jpg
#   Folder: Oswald_Gruebel
#     File: Oswald_Gruebel_0001.jpg
#   Folder: Kurt_Tanabe
#     File: Kurt_Tanabe_0001.jpg
#   Folder: Julie_Taymor
#     File: Julie_Taymor_0002.jpg
#     File: Julie_Taymor_0001.jpg
#   Folder: Choi_Yun-yong
#     File: Choi_Yun-yong_0001.jpg
#   Folder: Lemuel_Montulo
#     File: Lemuel_Montulo_0001.jpg
#   Folder: Yu_Shyi-kun
#     File: Yu_Shyi-kun_0004.jpg
#     File: Yu_Shyi-kun_0003.jpg
#     File: Yu_Shyi-kun_0001.jpg
#     File: Yu_Shyi-kun_0002.jpg
#   Folder: Douglas_Meester
#     File: Douglas_Meester_0001.jpg
#   Folder: Jamie_Lee_Curtis
#     File: Jamie_Lee_Curtis_0001.jpg
#   Folder: Bill_Lerach
#     File: Bill_Lerach_0001.jpg
#   Folder: John_Wayne
#     File: John_Wayne_0001.jpg
#   Folder: Eddie_Fenech_Adami
#     File: Eddie_Fenech_Adami_0001.jpg
#   Folder: Natalia_Dmitrieva
#     File: Natalia_Dmitrieva_0001.jpg
#   Folder: Bob_Taft
#     File: Bob_Taft_0001.jpg
#   Folder: Augustin_Calleri
#     File: Augustin_Calleri_0004.jpg
#     File: Augustin_Calleri_0001.jpg
#     File: Augustin_Calleri_0002.jpg
#     File: Augustin_Calleri_0003.jpg
#   Folder: Debra_Brown
#     File: Debra_Brown_0001.jpg
#     File: Debra_Brown_0002.jpg
#   Folder: Buddy_Ryan
#     File: Buddy_Ryan_0001.jpg
#   Folder: Erin_Hershey_Presley
#     File: Erin_Hershey_Presley_0001.jpg
#   Folder: Dominik_Hrbaty
#     File: Dominik_Hrbaty_0001.jpg
#   Folder: Byron_Scott
#     File: Byron_Scott_0002.jpg
#     File: Byron_Scott_0001.jpg
#   Folder: Phan_Van_Khai
#     File: Phan_Van_Khai_0002.jpg
#     File: Phan_Van_Khai_0001.jpg
#     File: Phan_Van_Khai_0003.jpg
#   Folder: John_Baldacci
#     File: John_Baldacci_0001.jpg
#   Folder: Carlos_Quintanilla_Schmidt
#     File: Carlos_Quintanilla_Schmidt_0001.jpg
#     File: Carlos_Quintanilla_Schmidt_0002.jpg
#   Folder: Jerry_Regier
#     File: Jerry_Regier_0002.jpg
#     File: Jerry_Regier_0001.jpg
#     File: Jerry_Regier_0003.jpg
#     File: Jerry_Regier_0004.jpg
#   Folder: Daniel_Osorno
#     File: Daniel_Osorno_0001.jpg
#   Folder: Tangra_Riggle
#     File: Tangra_Riggle_0001.jpg
#   Folder: Ricardo_Lopez_Murphy
#     File: Ricardo_Lopez_Murphy_0002.jpg
#     File: Ricardo_Lopez_Murphy_0001.jpg
#   Folder: Will_Self
#     File: Will_Self_0001.jpg
#   Folder: Fernando_Sanz
#     File: Fernando_Sanz_0001.jpg
#   Folder: Ashton_Kutcher
#     File: Ashton_Kutcher_0003.jpg
#     File: Ashton_Kutcher_0002.jpg
#     File: Ashton_Kutcher_0001.jpg
#   Folder: Heidi_Fleiss
#     File: Heidi_Fleiss_0002.jpg
#     File: Heidi_Fleiss_0001.jpg
#     File: Heidi_Fleiss_0004.jpg
#     File: Heidi_Fleiss_0003.jpg
#   Folder: Hun_Sen
#     File: Hun_Sen_0004.jpg
#     File: Hun_Sen_0001.jpg
#     File: Hun_Sen_0003.jpg
#     File: Hun_Sen_0002.jpg
#   Folder: Jim_Talent
#     File: Jim_Talent_0001.jpg
#   Folder: John_F_Kennedy_Jr
#     File: John_F_Kennedy_Jr_0001.jpg
#     File: John_F_Kennedy_Jr_0002.jpg
#   Folder: Edwina_Currie
#     File: Edwina_Currie_0002.jpg
#     File: Edwina_Currie_0001.jpg
#     File: Edwina_Currie_0004.jpg
#     File: Edwina_Currie_0003.jpg
#   Folder: Matt_Roney
#     File: Matt_Roney_0001.jpg
#   Folder: Ben_Howland
#     File: Ben_Howland_0002.jpg
#     File: Ben_Howland_0004.jpg
#     File: Ben_Howland_0001.jpg
#     File: Ben_Howland_0003.jpg
#   Folder: Romeo_Gigli
#     File: Romeo_Gigli_0001.jpg
#   Folder: William_Bulger
#     File: William_Bulger_0002.jpg
#     File: William_Bulger_0004.jpg
#     File: William_Bulger_0003.jpg
#     File: William_Bulger_0001.jpg
#   Folder: Ozzie_Smith
#     File: Ozzie_Smith_0001.jpg
#   Folder: Rachel_Wheatley
#     File: Rachel_Wheatley_0001.jpg
#   Folder: Franz_Muentefering
#     File: Franz_Muentefering_0004.jpg
#     File: Franz_Muentefering_0001.jpg
#     File: Franz_Muentefering_0002.jpg
#     File: Franz_Muentefering_0003.jpg
#   Folder: Frank_Hsieh
#     File: Frank_Hsieh_0001.jpg
#   Folder: Bridgette_Wilson-Sampras
#     File: Bridgette_Wilson-Sampras_0002.jpg
#     File: Bridgette_Wilson-Sampras_0003.jpg
#     File: Bridgette_Wilson-Sampras_0001.jpg
#   Folder: Mireya_Moscoso
#     File: Mireya_Moscoso_0003.jpg
#     File: Mireya_Moscoso_0005.jpg
#     File: Mireya_Moscoso_0001.jpg
#     File: Mireya_Moscoso_0002.jpg
#     File: Mireya_Moscoso_0004.jpg
#   Folder: Kathleen_Kennedy_Townsend
#     File: Kathleen_Kennedy_Townsend_0001.jpg
#     File: Kathleen_Kennedy_Townsend_0002.jpg
#     File: Kathleen_Kennedy_Townsend_0004.jpg
#     File: Kathleen_Kennedy_Townsend_0003.jpg
#   Folder: Tatyana_Tomashova
#     File: Tatyana_Tomashova_0001.jpg
#   Folder: Donna_Morrissey
#     File: Donna_Morrissey_0001.jpg
#   Folder: Samuel_Waksal
#     File: Samuel_Waksal_0001.jpg
#     File: Samuel_Waksal_0002.jpg
#     File: Samuel_Waksal_0003.jpg
#     File: Samuel_Waksal_0004.jpg
#   Folder: Andy_Lau
#     File: Andy_Lau_0001.jpg
#   Folder: Dorothy_Loudon
#     File: Dorothy_Loudon_0001.jpg
#   Folder: Phillips_Idowu
#     File: Phillips_Idowu_0001.jpg
#   Folder: Queen_Rania
#     File: Queen_Rania_0005.jpg
# ...
#     File: Tony_Blair_0065.jpg
#     File: Tony_Blair_0087.jpg
#     File: Tony_Blair_0125.jpg
#     File: Tony_Blair_0127.jpg
#     File: Tony_Blair_0048.jpg
#     File: Tony_Blair_0018.jpg
#     File: Tony_Blair_0060.jpg
#     File: Tony_Blair_0042.jpg
#     File: Tony_Blair_0130.jpg
#     File: Tony_Blair_0120.jpg
#     File: Tony_Blair_0008.jpg
#     File: Tony_Blair_0126.jpg
#     File: Tony_Blair_0003.jpg
#     File: Tony_Blair_0026.jpg
#     File: Tony_Blair_0013.jpg
#     File: Tony_Blair_0020.jpg
#     File: Tony_Blair_0053.jpg
#     File: Tony_Blair_0072.jpg
#     File: Tony_Blair_0117.jpg
#     File: Tony_Blair_0024.jpg
#     File: Tony_Blair_0040.jpg
#     File: Tony_Blair_0082.jpg
#     File: Tony_Blair_0046.jpg
#     File: Tony_Blair_0101.jpg
#     File: Tony_Blair_0104.jpg
#     File: Tony_Blair_0119.jpg
#     File: Tony_Blair_0050.jpg
#     File: Tony_Blair_0118.jpg
#     File: Tony_Blair_0136.jpg
#     File: Tony_Blair_0057.jpg
#     File: Tony_Blair_0133.jpg
#     File: Tony_Blair_0102.jpg
#     File: Tony_Blair_0129.jpg
#     File: Tony_Blair_0062.jpg
#     File: Tony_Blair_0122.jpg
#     File: Tony_Blair_0096.jpg
#     File: Tony_Blair_0098.jpg
#     File: Tony_Blair_0074.jpg
#     File: Tony_Blair_0055.jpg
#     File: Tony_Blair_0109.jpg
#     File: Tony_Blair_0002.jpg
#     File: Tony_Blair_0140.jpg
#     File: Tony_Blair_0017.jpg
#     File: Tony_Blair_0078.jpg
#     File: Tony_Blair_0107.jpg
#     File: Tony_Blair_0037.jpg
#     File: Tony_Blair_0023.jpg
#     File: Tony_Blair_0030.jpg
#     File: Tony_Blair_0141.jpg
#     File: Tony_Blair_0056.jpg
#     File: Tony_Blair_0097.jpg
#     File: Tony_Blair_0093.jpg
#     File: Tony_Blair_0105.jpg
#     File: Tony_Blair_0076.jpg
#     File: Tony_Blair_0039.jpg
#     File: Tony_Blair_0085.jpg
#     File: Tony_Blair_0033.jpg
#     File: Tony_Blair_0108.jpg
#     File: Tony_Blair_0004.jpg
#     File: Tony_Blair_0089.jpg
#     File: Tony_Blair_0022.jpg
#     File: Tony_Blair_0132.jpg
#     File: Tony_Blair_0110.jpg
#     File: Tony_Blair_0027.jpg
#     File: Tony_Blair_0106.jpg
#     File: Tony_Blair_0124.jpg
#     File: Tony_Blair_0049.jpg
#     File: Tony_Blair_0070.jpg
#     File: Tony_Blair_0005.jpg
#     File: Tony_Blair_0094.jpg
#     File: Tony_Blair_0073.jpg
#     File: Tony_Blair_0123.jpg
#     File: Tony_Blair_0077.jpg
#     File: Tony_Blair_0034.jpg
#     File: Tony_Blair_0014.jpg
#     File: Tony_Blair_0079.jpg
#     File: Tony_Blair_0012.jpg
#     File: Tony_Blair_0052.jpg
#     File: Tony_Blair_0063.jpg
#     File: Tony_Blair_0088.jpg
#     File: Tony_Blair_0112.jpg
#     File: Tony_Blair_0059.jpg
#     File: Tony_Blair_0083.jpg
#     File: Tony_Blair_0100.jpg
#     File: Tony_Blair_0111.jpg
#     File: Tony_Blair_0011.jpg
#     File: Tony_Blair_0041.jpg
#     File: Tony_Blair_0143.jpg
#     File: Tony_Blair_0114.jpg
#     File: Tony_Blair_0103.jpg
#     File: Tony_Blair_0066.jpg
#     File: Tony_Blair_0068.jpg
#     File: Tony_Blair_0006.jpg
#     File: Tony_Blair_0047.jpg
#     File: Tony_Blair_0015.jpg
#     File: Tony_Blair_0090.jpg
#     File: Tony_Blair_0081.jpg
#     File: Tony_Blair_0045.jpg
#     File: Tony_Blair_0016.jpg
#     File: Tony_Blair_0138.jpg
#     File: Tony_Blair_0069.jpg
#     File: Tony_Blair_0058.jpg
#     File: Tony_Blair_0115.jpg
#     File: Tony_Blair_0032.jpg
#     File: Tony_Blair_0051.jpg
#     File: Tony_Blair_0019.jpg
#     File: Tony_Blair_0099.jpg
#     File: Tony_Blair_0091.jpg
#     File: Tony_Blair_0144.jpg
#     File: Tony_Blair_0142.jpg
#     File: Tony_Blair_0021.jpg
#     File: Tony_Blair_0095.jpg
#     File: Tony_Blair_0128.jpg
#     File: Tony_Blair_0064.jpg
#     File: Tony_Blair_0044.jpg
#     File: Tony_Blair_0001.jpg
#     File: Tony_Blair_0028.jpg
#     File: Tony_Blair_0009.jpg
#     File: Tony_Blair_0092.jpg
#     File: Tony_Blair_0075.jpg
#     File: Tony_Blair_0137.jpg
#     File: Tony_Blair_0043.jpg
#     File: Tony_Blair_0010.jpg
#   Folder: Andres_Pastrana
#     File: Andres_Pastrana_0001.jpg
#   Folder: Isidro_Pastor
#     File: Isidro_Pastor_0001.jpg
#   Folder: Khalid_Khannouchi
#     File: Khalid_Khannouchi_0001.jpg
#   Folder: Teresa_Graves
#     File: Teresa_Graves_0001.jpg
#   Folder: Lazaro_Castro
#     File: Lazaro_Castro_0001.jpg
#   Folder: Sue_Guevara
#     File: Sue_Guevara_0001.jpg
#   Folder: David_Wells
#     File: David_Wells_0002.jpg
#     File: David_Wells_0004.jpg
#     File: David_Wells_0007.jpg
#     File: David_Wells_0003.jpg
#     File: David_Wells_0006.jpg
#     File: David_Wells_0005.jpg
#     File: David_Wells_0001.jpg
#   Folder: Alex_Penelas
#     File: Alex_Penelas_0002.jpg
#     File: Alex_Penelas_0001.jpg
#   Folder: Steve_Zahn
#     File: Steve_Zahn_0001.jpg
#   Folder: Hassan_Wirajuda
#     File: Hassan_Wirajuda_0001.jpg
#     File: Hassan_Wirajuda_0002.jpg
#   Folder: Cristian_Barros
#     File: Cristian_Barros_0001.jpg
#   Folder: John_Geoghan
#     File: John_Geoghan_0001.jpg
#   Folder: Luis_Figo
#     File: Luis_Figo_0003.jpg
#     File: Luis_Figo_0002.jpg
#     File: Luis_Figo_0004.jpg
#     File: Luis_Figo_0001.jpg
#   Folder: Russell_Coutts
#     File: Russell_Coutts_0002.jpg
#     File: Russell_Coutts_0001.jpg
#   Folder: Tippi_Hedren
#     File: Tippi_Hedren_0002.jpg
#     File: Tippi_Hedren_0001.jpg
#   Folder: Tatjana_Gsell
#     File: Tatjana_Gsell_0001.jpg
#   Folder: Ed_Mekertichian
#     File: Ed_Mekertichian_0001.jpg
#   Folder: Gianna_Angelopoulos-Daskalaki
#     File: Gianna_Angelopoulos-Daskalaki_0002.jpg
#     File: Gianna_Angelopoulos-Daskalaki_0003.jpg
#     File: Gianna_Angelopoulos-Daskalaki_0001.jpg
#   Folder: Daniel_Montgomery
#     File: Daniel_Montgomery_0001.jpg
#   Folder: James_Mathis
#     File: James_Mathis_0001.jpg
#   Folder: Larry_Johnson
#     File: Larry_Johnson_0002.jpg
#     File: Larry_Johnson_0001.jpg
#   Folder: Stacey_Yamaguchi
#     File: Stacey_Yamaguchi_0001.jpg
#   Folder: Yale_Kamisar
#     File: Yale_Kamisar_0001.jpg
#   Folder: Shane_Phillips
#     File: Shane_Phillips_0001.jpg
#   Folder: Heather_Willson
#     File: Heather_Willson_0001.jpg
#   Folder: Sergei_Ivanov
#     File: Sergei_Ivanov_0002.jpg
#     File: Sergei_Ivanov_0005.jpg
#     File: Sergei_Ivanov_0004.jpg
#     File: Sergei_Ivanov_0001.jpg
#     File: Sergei_Ivanov_0003.jpg
#   Folder: Gholamreza_Aghazadeh
#     File: Gholamreza_Aghazadeh_0001.jpg
#   Folder: Andres_DAlessandro
#     File: Andres_DAlessandro_0001.jpg
#   Folder: Kathy_Bates
#     File: Kathy_Bates_0001.jpg
#   Folder: Monica_Serra
#     File: Monica_Serra_0001.jpg
#   Folder: Grace_Dodd
#     File: Grace_Dodd_0001.jpg
#   Folder: Sherri_Coale
#     File: Sherri_Coale_0001.jpg
#   Folder: Monique_Gagnon-Tremblay
#     File: Monique_Gagnon-Tremblay_0001.jpg
#   Folder: Lin_Yi-fu
#     File: Lin_Yi-fu_0001.jpg
#   Folder: Sanja_Papic
#     File: Sanja_Papic_0001.jpg
#   Folder: Rainer_Geulen
#     File: Rainer_Geulen_0001.jpg
#   Folder: Eric_Daze
#     File: Eric_Daze_0001.jpg
#   Folder: John_Leguizamo
#     File: John_Leguizamo_0001.jpg
#   Folder: John_Scarlett
#     File: John_Scarlett_0001.jpg
#   Folder: Matthew_Ouimet
#     File: Matthew_Ouimet_0001.jpg
#   Folder: Monica_Vergara
#     File: Monica_Vergara_0001.jpg
#   Folder: Ray_Wasden
#     File: Ray_Wasden_0001.jpg
#   Folder: John_Wolf
#     File: John_Wolf_0002.jpg
#     File: John_Wolf_0001.jpg
#   Folder: Wayne_Newton
#     File: Wayne_Newton_0001.jpg
#   Folder: Phil_Morris
#     File: Phil_Morris_0001.jpg
#   Folder: Pat_DAmuro
#     File: Pat_DAmuro_0001.jpg
#   Folder: Chris_Klein
#     File: Chris_Klein_0001.jpg
#   Folder: Giselle_Estefania_Tavarelli
#     File: Giselle_Estefania_Tavarelli_0001.jpg
#   Folder: Krishna_Bhadur_Mahara
#     File: Krishna_Bhadur_Mahara_0001.jpg
#   Folder: Emily_Mortimer
#     File: Emily_Mortimer_0001.jpg
#   Folder: Robby_Ginepri
#     File: Robby_Ginepri_0001.jpg
#     File: Robby_Ginepri_0002.jpg
#   Folder: Paul_Byrd
#     File: Paul_Byrd_0001.jpg
#     File: Paul_Byrd_0002.jpg
#   Folder: Tommy_Haas
#     File: Tommy_Haas_0003.jpg
#     File: Tommy_Haas_0006.jpg
#     File: Tommy_Haas_0002.jpg
#     File: Tommy_Haas_0001.jpg
#     File: Tommy_Haas_0004.jpg
#     File: Tommy_Haas_0005.jpg
#   Folder: Amy_Smart
#     File: Amy_Smart_0001.jpg
#   Folder: Katie_Couric
#     File: Katie_Couric_0001.jpg
#   Folder: Demetrin_Veal
#     File: Demetrin_Veal_0001.jpg
#   Folder: Felix_Sanchez
#     File: Felix_Sanchez_0001.jpg
#   Folder: Sandra_Milo
#     File: Sandra_Milo_0001.jpg
#   Folder: Naomi_Watts
#     File: Naomi_Watts_0006.jpg
#     File: Naomi_Watts_0005.jpg
#     File: Naomi_Watts_0012.jpg
#     File: Naomi_Watts_0007.jpg
#     File: Naomi_Watts_0014.jpg
#     File: Naomi_Watts_0019.jpg
#     File: Naomi_Watts_0010.jpg
#     File: Naomi_Watts_0022.jpg
#     File: Naomi_Watts_0020.jpg
#     File: Naomi_Watts_0003.jpg
#     File: Naomi_Watts_0021.jpg
#     File: Naomi_Watts_0016.jpg
#     File: Naomi_Watts_0009.jpg
#     File: Naomi_Watts_0018.jpg
#     File: Naomi_Watts_0011.jpg
#     File: Naomi_Watts_0001.jpg
#     File: Naomi_Watts_0008.jpg
#     File: Naomi_Watts_0015.jpg
#     File: Naomi_Watts_0004.jpg
#     File: Naomi_Watts_0017.jpg
#     File: Naomi_Watts_0002.jpg
#     File: Naomi_Watts_0013.jpg
#   Folder: Dick_Clark
#     File: Dick_Clark_0001.jpg
#     File: Dick_Clark_0002.jpg
#     File: Dick_Clark_0003.jpg
#   Folder: Dino_de_Laurentis
#     File: Dino_de_Laurentis_0002.jpg
#     File: Dino_de_Laurentis_0001.jpg
#   Folder: Mae_Jemison
#     File: Mae_Jemison_0001.jpg
#   Folder: David_Ho
#     File: David_Ho_0001.jpg
#   Folder: Billy_Bob_Thornton
#     File: Billy_Bob_Thornton_0001.jpg
#   Folder: Luke_Ridnour
#     File: Luke_Ridnour_0001.jpg
#   Folder: Edgar_Savisaar
#     File: Edgar_Savisaar_0001.jpg
#   Folder: Shawn_Kemp
#     File: Shawn_Kemp_0001.jpg
#   Folder: Diana_Ross
#     File: Diana_Ross_0001.jpg
#   Folder: Roman_Abramovich
#     File: Roman_Abramovich_0001.jpg
#   Folder: Saoud_Al_Faisal
#     File: Saoud_Al_Faisal_0001.jpg
#   Folder: Terence_Newman
#     File: Terence_Newman_0001.jpg
#   Folder: Princess_Victoria
#     File: Princess_Victoria_0001.jpg
#   Folder: Jacqueline_Marris
#     File: Jacqueline_Marris_0001.jpg
#   Folder: Koichi_Haraguchi
#     File: Koichi_Haraguchi_0001.jpg
#   Folder: Gary_Stevens
#     File: Gary_Stevens_0001.jpg
#   Folder: Vicki_Zhao_Wei
#     File: Vicki_Zhao_Wei_0001.jpg
#     File: Vicki_Zhao_Wei_0002.jpg
#   Folder: Morris_Dees
#     File: Morris_Dees_0001.jpg
#   Folder: Richard_Virenque
#     File: Richard_Virenque_0005.jpg
#     File: Richard_Virenque_0003.jpg
#     File: Richard_Virenque_0002.jpg
#     File: Richard_Virenque_0004.jpg
#     File: Richard_Virenque_0001.jpg
#     File: Richard_Virenque_0008.jpg
#     File: Richard_Virenque_0006.jpg
#     File: Richard_Virenque_0007.jpg
#   Folder: Anthony_Lee_Johnson
#     File: Anthony_Lee_Johnson_0001.jpg
#   Folder: Dennis_Franchione
#     File: Dennis_Franchione_0001.jpg
#   Folder: Michelle_Pfeiffer
#     File: Michelle_Pfeiffer_0001.jpg
#     File: Michelle_Pfeiffer_0002.jpg
#     File: Michelle_Pfeiffer_0003.jpg
#   Folder: Reina_Hayes
#     File: Reina_Hayes_0001.jpg
#   Folder: Kim_Weeks
#     File: Kim_Weeks_0001.jpg
#   Folder: Jason_Kidd
#     File: Jason_Kidd_0007.jpg
#     File: Jason_Kidd_0002.jpg
#     File: Jason_Kidd_0004.jpg
#     File: Jason_Kidd_0008.jpg
#     File: Jason_Kidd_0006.jpg
#     File: Jason_Kidd_0009.jpg
#     File: Jason_Kidd_0001.jpg
#     File: Jason_Kidd_0010.jpg
#     File: Jason_Kidd_0003.jpg
#     File: Jason_Kidd_0005.jpg
#   Folder: Abraham_Foxman
#     File: Abraham_Foxman_0001.jpg
#   Folder: Laura_Morante
#     File: Laura_Morante_0001.jpg
#   Folder: Tyron_Garner
#     File: Tyron_Garner_0002.jpg
#     File: Tyron_Garner_0001.jpg
#   Folder: Joshua_Gracin
#     File: Joshua_Gracin_0001.jpg
#   Folder: Kimberly_Bruckner
#     File: Kimberly_Bruckner_0001.jpg
#   Folder: Naomi_Hayashi
#     File: Naomi_Hayashi_0001.jpg
#   Folder: Terry_Gilliam
#     File: Terry_Gilliam_0001.jpg
#   Folder: Charles_Grassley
#     File: Charles_Grassley_0001.jpg
#     File: Charles_Grassley_0002.jpg
#   Folder: Shae-Lynn_Bourne
#     File: Shae-Lynn_Bourne_0001.jpg
#   Folder: Alvaro_Silva_Calderon
#     File: Alvaro_Silva_Calderon_0003.jpg
#     File: Alvaro_Silva_Calderon_0001.jpg
#     File: Alvaro_Silva_Calderon_0002.jpg
#     File: Alvaro_Silva_Calderon_0004.jpg
#   Folder: Mark_Mishkin
#     File: Mark_Mishkin_0001.jpg
#   Folder: Cheryl_Hines
#     File: Cheryl_Hines_0001.jpg
#   Folder: Joaquim_Rodriguez
#     File: Joaquim_Rodriguez_0001.jpg
#   Folder: Edward_Lohn
#     File: Edward_Lohn_0001.jpg
#   Folder: Jose_Cevallos
#     File: Jose_Cevallos_0001.jpg
#   Folder: Seymour_Cassell
#     File: Seymour_Cassell_0001.jpg
#   Folder: Drew_Bledsoe
#     File: Drew_Bledsoe_0001.jpg
#   Folder: Tina_Andrews
#     File: Tina_Andrews_0001.jpg
#   Folder: Gilles_Panizzi
#     File: Gilles_Panizzi_0001.jpg
#   Folder: Christiane_Wulff
#     File: Christiane_Wulff_0001.jpg
#   Folder: Cecilia_Cheung
#     File: Cecilia_Cheung_0001.jpg
#   Folder: Charlie_Garner
#     File: Charlie_Garner_0001.jpg
#   Folder: Junichi_Inamoto
#     File: Junichi_Inamoto_0001.jpg
#   Folder: Lleyton_Hewitt
#     File: Lleyton_Hewitt_0024.jpg
#     File: Lleyton_Hewitt_0021.jpg
#     File: Lleyton_Hewitt_0009.jpg
#     File: Lleyton_Hewitt_0027.jpg
#     File: Lleyton_Hewitt_0032.jpg
#     File: Lleyton_Hewitt_0002.jpg
#     File: Lleyton_Hewitt_0008.jpg
#     File: Lleyton_Hewitt_0033.jpg
#     File: Lleyton_Hewitt_0035.jpg
#     File: Lleyton_Hewitt_0038.jpg
#     File: Lleyton_Hewitt_0010.jpg
#     File: Lleyton_Hewitt_0025.jpg
#     File: Lleyton_Hewitt_0029.jpg
#     File: Lleyton_Hewitt_0039.jpg
#     File: Lleyton_Hewitt_0026.jpg
#     File: Lleyton_Hewitt_0018.jpg
#     File: Lleyton_Hewitt_0016.jpg
#     File: Lleyton_Hewitt_0031.jpg
#     File: Lleyton_Hewitt_0036.jpg
#     File: Lleyton_Hewitt_0020.jpg
#     File: Lleyton_Hewitt_0004.jpg
#     File: Lleyton_Hewitt_0017.jpg
#     File: Lleyton_Hewitt_0019.jpg
#     File: Lleyton_Hewitt_0005.jpg
#     File: Lleyton_Hewitt_0011.jpg
#     File: Lleyton_Hewitt_0023.jpg
#     File: Lleyton_Hewitt_0022.jpg
#     File: Lleyton_Hewitt_0012.jpg
#     File: Lleyton_Hewitt_0041.jpg
#     File: Lleyton_Hewitt_0013.jpg
#     File: Lleyton_Hewitt_0030.jpg
#     File: Lleyton_Hewitt_0028.jpg
#     File: Lleyton_Hewitt_0014.jpg
#     File: Lleyton_Hewitt_0040.jpg
#     File: Lleyton_Hewitt_0006.jpg
#     File: Lleyton_Hewitt_0001.jpg
#     File: Lleyton_Hewitt_0003.jpg
#     File: Lleyton_Hewitt_0015.jpg
#     File: Lleyton_Hewitt_0037.jpg
#     File: Lleyton_Hewitt_0034.jpg
#     File: Lleyton_Hewitt_0007.jpg
#   Folder: Jelena_Dokic
#     File: Jelena_Dokic_0005.jpg
#     File: Jelena_Dokic_0006.jpg
#     File: Jelena_Dokic_0001.jpg
#     File: Jelena_Dokic_0002.jpg
#     File: Jelena_Dokic_0004.jpg
#     File: Jelena_Dokic_0007.jpg
#     File: Jelena_Dokic_0003.jpg
#     File: Jelena_Dokic_0008.jpg
#   Folder: Tracee_Ellis_Ross
#     File: Tracee_Ellis_Ross_0001.jpg
#     File: Tracee_Ellis_Ross_0002.jpg
#   Folder: Cassandra_Heise
#     File: Cassandra_Heise_0001.jpg
#   Folder: Joe_Garner
#     File: Joe_Garner_0001.jpg
#   Folder: Eric_Clapton
#     File: Eric_Clapton_0001.jpg
#     File: Eric_Clapton_0002.jpg
#   Folder: Tom_Welch
#     File: Tom_Welch_0001.jpg
#   Folder: Nicola_Wells
#     File: Nicola_Wells_0001.jpg
#   Folder: Gloria_Allred
#     File: Gloria_Allred_0002.jpg
#     File: Gloria_Allred_0001.jpg
#   Folder: Anthony_Carter
#     File: Anthony_Carter_0001.jpg
#   Folder: William_Martin
#     File: William_Martin_0002.jpg
#     File: William_Martin_0001.jpg
#   Folder: Eric_Dubin
#     File: Eric_Dubin_0001.jpg
#   Folder: Kevin_Tarrant
#     File: Kevin_Tarrant_0001.jpg
#   Folder: Todd_Haynes
#     File: Todd_Haynes_0003.jpg
#     File: Todd_Haynes_0004.jpg
#     File: Todd_Haynes_0001.jpg
#     File: Todd_Haynes_0002.jpg
#   Folder: Phil_Gramm
#     File: Phil_Gramm_0002.jpg
#     File: Phil_Gramm_0001.jpg
#   Folder: Julia_Glass
#     File: Julia_Glass_0001.jpg
#   Folder: Luiz_Felipe_Scolari
#     File: Luiz_Felipe_Scolari_0001.jpg
#     File: Luiz_Felipe_Scolari_0002.jpg
#   Folder: Michael_Douglas
#     File: Michael_Douglas_0004.jpg
#     File: Michael_Douglas_0002.jpg
#     File: Michael_Douglas_0006.jpg
#     File: Michael_Douglas_0003.jpg
#     File: Michael_Douglas_0005.jpg
#     File: Michael_Douglas_0001.jpg
#   Folder: Jason_Vale
#     File: Jason_Vale_0001.jpg
#   Folder: Eric_Snow
#     File: Eric_Snow_0001.jpg
#   Folder: Petria_Thomas
#     File: Petria_Thomas_0003.jpg
#     File: Petria_Thomas_0001.jpg
#     File: Petria_Thomas_0002.jpg
#   Folder: Jeanne_Moreau
#     File: Jeanne_Moreau_0001.jpg
#     File: Jeanne_Moreau_0002.jpg
#   Folder: Richard_Parsons
#     File: Richard_Parsons_0001.jpg
#   Folder: James_Murdoch
#     File: James_Murdoch_0001.jpg
#   Folder: Mickey_Rooney
#     File: Mickey_Rooney_0001.jpg
#
# Folder: lfw-deepfunneled
# x

# %%
import os

def count_folders_and_images(folder_path):
    num_folders = 0
    num_images = 0

    # List all items (files and directories) in the folder
    items = os.listdir(folder_path)

    for item in items:
        item_path = os.path.join(folder_path, item)
        # Check if the item is a directory
        if os.path.isdir(item_path):
            num_folders += 1
        else:
            num_images += 1

    return num_folders, num_images

def print_folder_contents(folder_path, indent=''):
    # List all directories in the folder
    subfolders = [name for name in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, name))]

    for subfolder in subfolders:
        print(indent + "Subfolder:", subfolder)
        num_folders, num_images = count_folders_and_images(os.path.join(folder_path, subfolder))
        print(indent + "Number of folders:", num_folders)
        print(indent + "Number of images:", num_images)

dataset_path = 'lfw-dataset'

# List all directories in the dataset folder
folders = [name for name in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, name))]

# Print number of folders
print("Number of folders in the dataset:", len(folders))

# Print details of each folder
for folder in folders:
    print("\nFolder:", folder)
    num_folders, num_images = count_folders_and_images(os.path.join(dataset_path, folder))
    print("Number of folders:", num_folders)
    print("Number of images:", num_images)
    print_folder_contents(os.path.join(dataset_path, folder), '  ')
# Out:
# Number of folders in the dataset: 1
#
# Folder: lfw-deepfunneled
# Number of folders: 1
# Number of images: 0
#   Subfolder: lfw-deepfunneled
#   Number of folders: 5749
#   Number of images: 0

# %%
import os
import matplotlib.pyplot as plt

def count_images_in_folder(folder_path):
    # List all files in the folder with image file formats
    image_formats = ['.jpg', '.jpeg', '.png', '.gif', '.bmp']  # Add more image file formats if needed
    image_files = [name for name in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, name)) and any(name.lower().endswith(fmt) for fmt in image_formats)]
    return len(image_files)

def count_images_per_person(dataset_path):
    # List all directories in the dataset folder
    folders = [name for name in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, name))]
    person_names = []
    num_images = []

    # Function to recursively traverse through subfolders
    def traverse(folder_path):
        for name in os.listdir(folder_path):
            sub_path = os.path.join(folder_path, name)
            if os.path.isdir(sub_path):
                traverse(sub_path)
            elif os.path.isfile(sub_path):
                num_images.append(count_images_in_folder(folder_path))
                person_names.append(os.path.basename(folder_path))
                break

    # Iterate through each folder in the dataset
    for folder in folders:
        folder_path = os.path.join(dataset_path, folder)
        traverse(folder_path)

    return person_names, num_images

dataset_path = 'lfw-dataset'

person_names, num_images = count_images_per_person(dataset_path)

plt.figure(figsize=(12, 6))
plt.plot(person_names, num_images, marker='o', color='skyblue', linestyle='-')
plt.xlabel('Person')
plt.ylabel('Number of Images')
plt.title('Number of Images for Each Person')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def extract_features(image_path, model):
    image = Image.open(image_path).convert('RGB')
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    image = preprocess(image)
    image = image.unsqueeze(0)
    with torch.no_grad():
        features = model(image)
    features = features.squeeze(0)
    return features


def compute_hog(img):
    resized_img = resize(img, (128*4, 64*4))
    fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),
                    cells_per_block=(2, 2), visualize=True, multichannel=True)
    return fd


def get_pixel(img, center, x, y):
    new_value = 0
    try:
        if img[x][y] >= center:
            new_value = 1
    except:
        pass
    return new_value

def lbp_calculated_pixel(img, x, y):
    center = img[x][y]
    val_ar = []
    val_ar.append(get_pixel(img, center, x-1, y+1))
    val_ar.append(get_pixel(img, center, x, y+1))
    val_ar.append(get_pixel(img, center, x+1, y+1))
    val_ar.append(get_pixel(img, center, x+1, y))
    val_ar.append(get_pixel(img, center, x+1, y-1))
    val_ar.append(get_pixel(img, center, x, y-1))
    val_ar.append(get_pixel(img, center, x-1, y-1))
    val_ar.append(get_pixel(img, center, x-1, y))

    power_val = [1, 2, 4, 8, 16, 32, 64, 128]
    val = 0
    for i in range(len(val_ar)):
        val += val_ar[i] * power_val[i]
    return val

def calcLBP(img):
    height, width, channel = img.shape
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_lbp = np.zeros((height, width,3), np.uint8)
    for i in range(0, height):
        for j in range(0, width):
             img_lbp[i, j] = lbp_calculated_pixel(img_gray, i, j)
    hist_lbp = cv2.calcHist([img_lbp], [0], None, [256], [0, 256])
    return hist_lbp.flatten()

# %%
resnet = models.resnet50(pretrained=True)
resnet = nn.Sequential(*list(resnet.children())[:-1])
resnet.eval()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (5): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (6): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (7): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %%
lfw_folder = '/content/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled'
X, y = [], []
for folder_name in os.listdir(lfw_folder):
    folder_path = os.path.join(lfw_folder, folder_name)
    if os.path.isdir(folder_path):
        num_images = len(os.listdir(folder_path))
        if num_images > 70:
            for image_name in os.listdir(folder_path):
                image_path = os.path.join(folder_path, image_name)
                image = imread(image_path)
                hog_feature = compute_hog(image)
                lbp_feature = calcLBP(image)
                cnn_feature = extract_features(image_path, resnet).numpy()
                hog_feature = hog_feature.reshape(-1)
                lbp_feature = lbp_feature.reshape(-1)
                cnn_feature = cnn_feature.flatten()
                combined_feature = np.concatenate((hog_feature, lbp_feature, cnn_feature))

                X.append(combined_feature)
                y.append(folder_name)
# Out:
# <ipython-input-3-8d0f7df1f55f>:19: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
knn_clf = KNeighborsClassifier()
knn_clf.fit(X_train, y_train_encoded)
y_pred_knn = knn_clf.predict(X_test)
accuracy_knn = accuracy_score(y_test_encoded, y_pred_knn)
print("KNN Classifier")
print("Accuracy:", accuracy_knn)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_knn, target_names=label_encoder.classes_))
# Out:
# KNN Classifier
# Accuracy: 0.3798449612403101
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.25      0.12      0.17        16
#      Colin_Powell       0.30      0.45      0.36        38
#   Donald_Rumsfeld       0.29      0.19      0.23        26
#     George_W_Bush       0.47      0.61      0.53       109
# Gerhard_Schroeder       0.06      0.06      0.06        18
#       Hugo_Chavez       0.33      0.05      0.08        21
#        Tony_Blair       0.36      0.17      0.23        30
#
#          accuracy                           0.38       258
#         macro avg       0.29      0.24      0.24       258
#      weighted avg       0.36      0.38      0.35       258

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.95)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)


knn_clf = KNeighborsClassifier()
knn_clf.fit(X_train_pca, y_train_encoded)
y_pred_knn = knn_clf.predict(X_test_pca)
accuracy_knn = accuracy_score(y_test_encoded, y_pred_knn)

print("KNN Classifier")
print("Accuracy:", accuracy_knn)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_knn, target_names=label_encoder.classes_))
# Out:
# KNN Classifier
# Accuracy: 0.3875968992248062
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.09      0.06      0.07        16
#      Colin_Powell       0.32      0.47      0.38        38
#   Donald_Rumsfeld       0.19      0.15      0.17        26
#     George_W_Bush       0.52      0.68      0.59       109
# Gerhard_Schroeder       0.17      0.11      0.13        18
#       Hugo_Chavez       0.00      0.00      0.00        21
#        Tony_Blair       0.08      0.03      0.05        30
#
#          accuracy                           0.39       258
#         macro avg       0.19      0.22      0.20       258
#      weighted avg       0.31      0.39      0.34       258

# %%
svm_clf = SVC()
svm_clf.fit(X_train, y_train_encoded)
y_pred_svm = svm_clf.predict(X_test)
accuracy_svm = accuracy_score(y_test_encoded, y_pred_svm)
print("SVM Classifier")
print("Accuracy:", accuracy_svm)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_svm, target_names=label_encoder.classes_))
# Out:
# SVM Classifier
# Accuracy: 0.4263565891472868
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.00      0.00      0.00        16
#      Colin_Powell       0.38      0.34      0.36        38
#   Donald_Rumsfeld       0.00      0.00      0.00        26
#     George_W_Bush       0.43      0.89      0.58       109
# Gerhard_Schroeder       0.00      0.00      0.00        18
#       Hugo_Chavez       0.00      0.00      0.00        21
#        Tony_Blair       0.00      0.00      0.00        30
#
#          accuracy                           0.43       258
#         macro avg       0.12      0.18      0.13       258
#      weighted avg       0.24      0.43      0.30       258
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svm_clf = SVC()
svm_clf.fit(X_train_pca, y_train_encoded)
y_pred_svm = svm_clf.predict(X_test_pca)
accuracy_svm = accuracy_score(y_test_encoded, y_pred_svm)
print("SVM Classifier")
print("Accuracy:", accuracy_svm)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_svm, target_names=label_encoder.classes_))
# Out:
# SVM Classifier
# Accuracy: 0.4263565891472868
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.00      0.00      0.00        16
#      Colin_Powell       0.36      0.37      0.36        38
#   Donald_Rumsfeld       0.67      0.08      0.14        26
#     George_W_Bush       0.44      0.86      0.58       109
# Gerhard_Schroeder       0.00      0.00      0.00        18
#       Hugo_Chavez       0.00      0.00      0.00        21
#        Tony_Blair       0.00      0.00      0.00        30
#
#          accuracy                           0.43       258
#         macro avg       0.21      0.19      0.15       258
#      weighted avg       0.30      0.43      0.31       258
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.ensemble import AdaBoostClassifier
adaboost_clf = AdaBoostClassifier()
adaboost_clf.fit(X_train, y_train_encoded)
y_pred_adaboost = adaboost_clf.predict(X_test)
accuracy_adaboost = accuracy_score(y_test_encoded, y_pred_adaboost)

print("AdaBoost Classifier")
print("Accuracy:", accuracy_adaboost)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_adaboost, target_names=label_encoder.classes_))
# Out:
# AdaBoost Classifier
# Accuracy: 0.49224806201550386
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.00      0.00      0.00        16
#      Colin_Powell       0.43      0.47      0.45        38
#   Donald_Rumsfeld       0.00      0.00      0.00        26
#     George_W_Bush       0.53      0.85      0.65       109
# Gerhard_Schroeder       0.83      0.28      0.42        18
#       Hugo_Chavez       0.23      0.24      0.23        21
#        Tony_Blair       0.55      0.20      0.29        30
#
#          accuracy                           0.49       258
#         macro avg       0.37      0.29      0.29       258
#      weighted avg       0.43      0.49      0.43       258
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.ensemble import AdaBoostClassifier
adaboost_clf = AdaBoostClassifier()
adaboost_clf.fit(X_train_pca, y_train_encoded)
y_pred_adaboost = adaboost_clf.predict(X_test_pca)
accuracy_adaboost = accuracy_score(y_test_encoded, y_pred_adaboost)

print("AdaBoost Classifier")
print("Accuracy:", accuracy_adaboost)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_adaboost, target_names=label_encoder.classes_))
# Out:
# AdaBoost Classifier
# Accuracy: 0.32170542635658916
# Classification Report:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.20      0.06      0.10        16
#      Colin_Powell       0.22      0.34      0.27        38
#   Donald_Rumsfeld       0.07      0.04      0.05        26
#     George_W_Bush       0.39      0.62      0.48       109
# Gerhard_Schroeder       0.00      0.00      0.00        18
#       Hugo_Chavez       0.00      0.00      0.00        21
#        Tony_Blair       0.00      0.00      0.00        30
#
#          accuracy                           0.32       258
#         macro avg       0.13      0.15      0.13       258
#      weighted avg       0.22      0.32      0.25       258
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train, y_train_encoded)
y_pred_dt = dt_clf.predict(X_test)
accuracy_dt = accuracy_score(y_test_encoded, y_pred_dt)
print("Decision Tree Classifier")
print("Accuracy:", accuracy_dt)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_dt, target_names=label_encoder.classes_))
# Out:
# Decision Tree Classifier
# Accuracy: 0.5542635658914729
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.30      0.38      0.33        16
#      Colin_Powell       0.47      0.50      0.49        38
#   Donald_Rumsfeld       0.45      0.35      0.39        26
#     George_W_Bush       0.72      0.77      0.74       109
# Gerhard_Schroeder       0.35      0.39      0.37        18
#       Hugo_Chavez       0.33      0.29      0.31        21
#        Tony_Blair       0.52      0.40      0.45        30
#
#          accuracy                           0.55       258
#         macro avg       0.45      0.44      0.44       258
#      weighted avg       0.55      0.55      0.55       258

# %%
dt_clf = DecisionTreeClassifier()
dt_clf.fit(X_train_pca, y_train_encoded)
y_pred_dt = dt_clf.predict(X_test_pca)
accuracy_dt = accuracy_score(y_test_encoded, y_pred_dt)
print("Decision Tree Classifier")
print("Accuracy:", accuracy_dt)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_dt, target_names=label_encoder.classes_))
# Out:
# Decision Tree Classifier
# Accuracy: 0.2713178294573643
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.06      0.06      0.06        16
#      Colin_Powell       0.15      0.18      0.16        38
#   Donald_Rumsfeld       0.19      0.15      0.17        26
#     George_W_Bush       0.47      0.45      0.46       109
# Gerhard_Schroeder       0.12      0.17      0.14        18
#       Hugo_Chavez       0.18      0.10      0.12        21
#        Tony_Blair       0.13      0.13      0.13        30
#
#          accuracy                           0.27       258
#         macro avg       0.18      0.18      0.18       258
#      weighted avg       0.28      0.27      0.27       258

# %%
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, y_train_encoded)
y_pred_rf = rf_clf.predict(X_test)
accuracy_rf = accuracy_score(y_test_encoded, y_pred_rf)
print("Random Forest Classifier")
print("Accuracy:", accuracy_rf)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_rf, target_names=label_encoder.classes_))
# Out:
# Random Forest Classifier
# Accuracy: 0.6472868217054264
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       1.00      0.06      0.12        16
#      Colin_Powell       0.87      0.89      0.88        38
#   Donald_Rumsfeld       1.00      0.31      0.47        26
#     George_W_Bush       0.56      1.00      0.72       109
# Gerhard_Schroeder       1.00      0.28      0.43        18
#       Hugo_Chavez       0.00      0.00      0.00        21
#        Tony_Blair       1.00      0.33      0.50        30
#
#          accuracy                           0.65       258
#         macro avg       0.78      0.41      0.45       258
#      weighted avg       0.71      0.65      0.58       258
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
rt_clf = RandomForestClassifier()
rt_clf.fit(X_train_pca, y_train_encoded)
y_pred_dt = dt_clf.predict(X_test_pca)
accuracy_dt = accuracy_score(y_test_encoded, y_pred_dt)
print("Decision Tree Classifier")
print("Accuracy:", accuracy_dt)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_dt, target_names=label_encoder.classes_))
# Out:
# Decision Tree Classifier
# Accuracy: 0.29069767441860467
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.06      0.06      0.06        16
#      Colin_Powell       0.23      0.29      0.26        38
#   Donald_Rumsfeld       0.21      0.23      0.22        26
#     George_W_Bush       0.48      0.44      0.46       109
# Gerhard_Schroeder       0.07      0.11      0.09        18
#       Hugo_Chavez       0.25      0.10      0.14        21
#        Tony_Blair       0.17      0.17      0.17        30
#
#          accuracy                           0.29       258
#         macro avg       0.21      0.20      0.20       258
#      weighted avg       0.31      0.29      0.30       258

# %%
lr_clf = LogisticRegression(max_iter=1000)
lr_clf.fit(X_train, y_train_encoded)
y_pred_lr = lr_clf.predict(X_test)
accuracy_lr = accuracy_score(y_test_encoded, y_pred_lr)
print("Logistic Regression Classifier")
print("Accuracy:", accuracy_lr)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_lr, target_names=label_encoder.classes_))
# Out:
# Logistic Regression Classifier
# Accuracy: 0.5077519379844961
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.58      0.44      0.50        16
#      Colin_Powell       0.47      0.53      0.49        38
#   Donald_Rumsfeld       0.30      0.12      0.17        26
#     George_W_Bush       0.59      0.81      0.68       109
# Gerhard_Schroeder       0.22      0.22      0.22        18
#       Hugo_Chavez       0.29      0.10      0.14        21
#        Tony_Blair       0.39      0.23      0.29        30
#
#          accuracy                           0.51       258
#         macro avg       0.40      0.35      0.36       258
#      weighted avg       0.47      0.51      0.47       258
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
lr_clf = LogisticRegression(max_iter=500)
lr_clf.fit(X_train_pca, y_train_encoded)
y_pred_lr = lr_clf.predict(X_test_pca)
accuracy_lr = accuracy_score(y_test_encoded, y_pred_lr)
print("Logistic Regression Classifier")
print("Accuracy:", accuracy_lr)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_lr, target_names=label_encoder.classes_))
# Out:
# Logistic Regression Classifier
# Accuracy: 0.4263565891472868
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.00      0.00      0.00        16
#      Colin_Powell       0.37      0.42      0.40        38
#   Donald_Rumsfeld       0.38      0.12      0.18        26
#     George_W_Bush       0.44      0.83      0.58       109
# Gerhard_Schroeder       0.00      0.00      0.00        18
#       Hugo_Chavez       0.00      0.00      0.00        21
#        Tony_Blair       0.00      0.00      0.00        30
#
#          accuracy                           0.43       258
#         macro avg       0.17      0.20      0.16       258
#      weighted avg       0.28      0.43      0.32       258
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
nb_clf = GaussianNB()
nb_clf.fit(X_train, y_train_encoded)
y_pred_nb = nb_clf.predict(X_test)
accuracy_nb = accuracy_score(y_test_encoded, y_pred_nb)
print("Naive Bayes Classifier")
print("Accuracy:", accuracy_nb)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_nb, target_names=label_encoder.classes_))
# Out:
# Naive Bayes Classifier
# Accuracy: 0.49612403100775193
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.64      0.44      0.52        16
#      Colin_Powell       0.54      0.71      0.61        38
#   Donald_Rumsfeld       0.24      0.88      0.37        26
#     George_W_Bush       0.97      0.28      0.43       109
# Gerhard_Schroeder       0.67      0.33      0.44        18
#       Hugo_Chavez       0.83      0.48      0.61        21
#        Tony_Blair       0.52      0.83      0.64        30
#
#          accuracy                           0.50       258
#         macro avg       0.63      0.56      0.52       258
#      weighted avg       0.73      0.50      0.50       258

# %%
nb_clf = GaussianNB()
nb_clf.fit(X_train_pca, y_train_encoded)
y_pred_nb = nb_clf.predict(X_test_pca)
accuracy_nb = accuracy_score(y_test_encoded, y_pred_nb)
print("Naive Bayes Classifier")
print("Accuracy:", accuracy_nb)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_nb, target_names=label_encoder.classes_))
# Out:
# Naive Bayes Classifier
# Accuracy: 0.40310077519379844
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.00      0.00      0.00        16
#      Colin_Powell       0.37      0.42      0.40        38
#   Donald_Rumsfeld       0.21      0.23      0.22        26
#     George_W_Bush       0.44      0.75      0.55       109
# Gerhard_Schroeder       0.00      0.00      0.00        18
#       Hugo_Chavez       0.00      0.00      0.00        21
#        Tony_Blair       0.00      0.00      0.00        30
#
#          accuracy                           0.40       258
#         macro avg       0.15      0.20      0.17       258
#      weighted avg       0.26      0.40      0.31       258
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mlp_clf = MLPClassifier()
mlp_clf.fit(X_train, y_train_encoded)
y_pred_mlp = mlp_clf.predict(X_test)
accuracy_mlp = accuracy_score(y_test_encoded, y_pred_mlp)
print("MLP Classifier")
print("Accuracy:", accuracy_mlp)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_mlp, target_names=label_encoder.classes_))
# Out:
# MLP Classifier
# Accuracy: 0.1511627906976744
# Classification Report:
#                    precision    recall  f1-score   support
#
#      Ariel_Sharon       0.00      0.00      0.00        16
#      Colin_Powell       0.00      0.00      0.00        38
#   Donald_Rumsfeld       0.00      0.00      0.00        26
#     George_W_Bush       0.00      0.00      0.00       109
# Gerhard_Schroeder       0.16      0.50      0.24        18
#       Hugo_Chavez       0.00      0.00      0.00        21
#        Tony_Blair       0.15      1.00      0.26        30
#
#          accuracy                           0.15       258
#         macro avg       0.04      0.21      0.07       258
#      weighted avg       0.03      0.15      0.05       258
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mlp_clf = MLPClassifier()
mlp_clf.fit(X_train_pca, y_train_encoded)
y_pred_mlp = mlp_clf.predict(X_test_pca)
accuracy_mlp = accuracy_score(y_test_encoded, y_pred_mlp)
print("MLP Classifier")
print("Accuracy:", accuracy_mlp)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_mlp, target_names=label_encoder.classes_))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c67ab7adc6cd> in <cell line: 1>()
# ----> 1 mlp_clf = MLPClassifier()
#       2 mlp_clf.fit(X_train_pca, y_train_encoded)
#       3 y_pred_mlp = mlp_clf.predict(X_test_pca)
#       4 accuracy_mlp = accuracy_score(y_test_encoded, y_pred_mlp)
#       5 print("MLP Classifier")
#
# NameError: name 'MLPClassifier' is not defined

# %%
from xgboost import XGBClassifier

xgb_clf = XGBClassifier()
xgb_clf.fit(X_train, y_train_encoded)
y_pred_xgb = xgb_clf.predict(X_test)
accuracy_xgb = accuracy_score(y_test_encoded, y_pred_xgb)
print("XGBoost Classifier")
print("Accuracy:", accuracy_xgb)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_xgb, target_names=label_encoder.classes_))

# %%
from xgboost import XGBClassifier

xgb_clf = XGBClassifier()
xgb_clf.fit(X_train_pca, y_train_encoded)
y_pred_xgb = xgb_clf.predict(X_test_pca)
accuracy_xgb = accuracy_score(y_test_encoded, y_pred_xgb)
print("XGBoost Classifier")
print("Accuracy:", accuracy_xgb)
print("Classification Report:")
print(classification_report(y_test_encoded, y_pred_xgb, target_names=label_encoder.classes_))
